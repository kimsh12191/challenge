# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import os
import shutil
from mpl_toolkits.mplot3d import Axes3D
from six.moves import cPickle
import sys
import pandas as pd

from sklearn.preprocessing import OneHotEncoder

#from RNN import RNNmodel

# %%
pred_train_df, pred_valid_df, pred_test_df= cPickle.load(open('RNNReuslt.pkl', 'rb'))

# %%
pred_train_df.head()
# Out:
#                   date true_kor true_west pred_kor pred_west true_sum pred_sum
# 0  2003-04-03 00:00:00  54.4404         0  51.2394  -0.47064  54.4404  50.7688
# 1  2003-04-04 00:00:00  43.1769         0  47.6012  -0.79732  43.1769  46.8039
# 2  2003-04-05 00:00:00  26.2816         0  29.7679  0.192484  26.2816  29.9604
# 3  2003-04-06 00:00:00  28.1588         0  27.9009 -0.127498  28.1588  27.7734
# 4  2003-04-07 00:00:00  52.2022         0  50.5209 -0.599885  52.2022   49.921

# %%
pred_valid_df.head()
# Out:
#                   date true_kor true_west pred_kor  pred_west true_sum  \
# 0  2005-07-27 00:00:00  40.2166   11.5523  45.2935    9.48001   51.769
# 1  2005-07-28 00:00:00  41.5884   10.8303  39.6314    9.02833  52.4188
# 2  2005-07-29 00:00:00  37.8339   10.8303   39.651    11.1581  48.6643
# 3  2005-07-30 00:00:00  31.4801         0  27.9543   0.992505  31.4801
# 4  2005-07-31 00:00:00  21.6606         0  25.9383 -0.0447967  21.6606
#
#   pred_sum
# 0  54.7735
# 1  48.6597
# 2   50.809
# 3  28.9468
# 4  25.8935

# %%
pred_test_df.head()
# Out:
#                   date true_kor true_west pred_kor pred_west true_sum pred_sum
# 0  2003-06-12 00:00:00  43.8267         0  51.8472  0.313879  43.8267  52.1611
# 1  2004-02-27 00:00:00  44.1155         0  47.2411 -0.119784  44.1155  47.1213
# 2  2007-04-07 00:00:00  21.3718   7.22022  17.5448   11.1851  28.5921  28.7299
# 3  2007-12-08 00:00:00  13.7906   9.02527  16.2881   10.5596  22.8159  26.8477
# 4  2008-12-27 00:00:00  16.7509   12.9964  17.4343   12.2409  29.7473  29.6751

# %%
menuDfraw = cPickle.load(open('../../../../data/pickle/rawPickle/menu.pkl', 'rb'))
menuDfadd = pd.read_excel('../../../../data/raw/regVocab_0710_suhyun.xlsx')

# %%
menuDfadd.head()
# Out:
#     menu  count menuSimple (칼로리 검색을 위함) menuType(주식, 반찬, 소스, 음료, 국, 후식)  \
# 0     쌀밥  18260                      쌀밥                              주식
# 1   배추김치  13307                    배추김치                              반찬
# 2  야채샐러드   6016                   야채샐러드                              반찬
# 3     우유   5097                      우유                              음료
# 4    딸기잼   4106                     딸기잼                              소스
#
#   menuMaterial(육류, 해산물, 채소, 곡류 등) menuWeight (메인메뉴 판단을 위한)
# 0                              곡류                      NaN
# 1                              채소                      NaN
# 2                              채소                      NaN
# 3                             유제품                      NaN
# 4                               빵                      NaN

# %%
menuDfraw.type2.unique()
# Out:
# array(['morning', 'lunch_kor', 'dinner', 'lunch_west'], dtype=object)

# %%
menuDfraw.head(10)
# Out:
#          date   type                                               menu  \
# 1  2003-03-01   아침식사                     과일샐러드,닭죽,돈육마늘장조림,떡만두국,부추김무침,쌀밥
# 2  2003-03-01  아침식사2   딸기잼(중),비엔나구이,스크램블에그(경양식),야채샐러드,크림스프(경양식),토스트&모닝빵
# 3  2003-03-01   점심식사                   골뱅이야채무침,새우맛살튀김,쌀밥(사무직),열무겉절이,칼국수
# 4  2003-03-01   저녁식사                        감자으깸샐러드,비프까스,스위트피클,쌀밥,옥수수스프
# 5  2003-03-02   아침식사                   계란죽,곤약멸치조림,김치국,마카로니샐러드,쌀밥,오징어회무침
# 6  2003-03-02  아침식사2          딸기잼(중),삶은계란,야채샐러드,크림스프(경양식),토스트&모닝빵,후르츠펀치
# 7  2003-03-02   점심식사               갈비탕,깍두기(손칼),두부달걀전,생선묵조림,쌀밥,오이,풋고추,쌈장
# 8  2003-03-02   저녁식사                          계란탕,단무지잔파무침,자장소스,잡채밥,탕수만두
# 9  2003-03-03   아침식사               감자다시마국,녹두죽,멸치볶음,쇠고기팽이버섯볶음,쌀밥,우유,호박나물
# 10 2003-03-03  아침식사2  딸기&쵸코우유,딸기잼(중),야채샐러드,콘후레이크,크림스프(경양식),토스트&모닝빵,후...
#
#         type2    type1                                          menuSplit
# 1     morning  morning              [과일샐러드, 닭죽, 돈육마늘장조림, 떡만두국, 부추김무침, 쌀밥]
# 2     morning  morning  [딸기잼(중), 비엔나구이, 스크램블에그(경양식), 야채샐러드, 크림스프(경양식),...
# 3   lunch_kor    lunch             [골뱅이야채무침, 새우맛살튀김, 쌀밥(사무직), 열무겉절이, 칼국수]
# 4      dinner   dinner                  [감자으깸샐러드, 비프까스, 스위트피클, 쌀밥, 옥수수스프]
# 5     morning  morning            [계란죽, 곤약멸치조림, 김치국, 마카로니샐러드, 쌀밥, 오징어회무침]
# 6     morning  morning   [딸기잼(중), 삶은계란, 야채샐러드, 크림스프(경양식), 토스트&모닝빵, 후르츠펀치]
# 7   lunch_kor    lunch      [갈비탕, 깍두기(손칼), 두부달걀전, 생선묵조림, 쌀밥, 오이, 풋고추, 쌈장]
# 8      dinner   dinner                    [계란탕, 단무지잔파무침, 자장소스, 잡채밥, 탕수만두]
# 9     morning  morning       [감자다시마국, 녹두죽, 멸치볶음, 쇠고기팽이버섯볶음, 쌀밥, 우유, 호박나물]
# 10    morning  morning  [딸기&쵸코우유, 딸기잼(중), 야채샐러드, 콘후레이크, 크림스프(경양식), 토스트...

# %% [markdown]
# # 메뉴만들기
#
# - 일단 lunch_kor 부터 진행한다.
#     - menu split, 불러와서, 그메뉴들 count 랑 material받아옴.
#     - 그 후에 true와 pred사이의 차이와의 관계? 찾기??..?
# - 그다음 lunch_west 진행.

# %%
menuKor = pd.merge(pred_train_df[['date', 'true_kor', 'pred_kor']].set_index('date') ,
         menuDfraw.loc[menuDfraw.type2 == 'lunch_kor'][['date', 'menuSplit']].set_index('date'),
        left_index=True, right_index=True)

# %% [markdown]
# - kor menu 리스트 true, pred옆에 넣음

# %%
menuKor.head()
# Out:
#            true_kor pred_kor                                     menuSplit
# date
# 2003-04-03  54.4404  51.2394   [물미역오이무침, 쌀밥, 아욱국, 쭈꾸미볶음, 참치김치볶음, 통두부, 양념장]
# 2003-04-04  43.1769  47.6012      [꽁치양념구이, 도라지풋마늘무침, 부추전, 쌀밥, 어묵무국, 잔멸치볶음]
# 2003-04-05  26.2816  29.7679                              [비빔밥, 사과, 팽이버섯국]
# 2003-04-06  28.1588  27.9009   [돌나물겉절이, 쇠고기맑은국, 쌀밥, 양상치샐러드, 오징어회무침, 카레라이스]
# 2003-04-07  52.2022  50.5209  [꽈리고추찜, 닭불고기(180), 쌀밥, 오이양파무침, 콩나물국, 표고피망볶음]

# %% [markdown]
# - menuKor의 menuSplit에서 menuDfadd의 menu에 해당하는거 찾은 다음 menuMaterial로 바꿔줘야함

# %%
error = 0
menuKor['menuMeterial'] = 0
for date, menuEachDay in enumerate(menuKor['menuSplit']):
    MeterialEachDay = []
    for eachMenu in menuEachDay:
        try:
            MeterialEachDay.append(menuDfadd[['menu', 'menuMaterial(육류, 해산물, 채소, 곡류 등)']].\
                loc[menuDfadd.menu==eachMenu]['menuMaterial(육류, 해산물, 채소, 곡류 등)'].values[0])
        except:
            error += 1
            print ('error index : {}'.format(date))
            print ('error menu : {}'.format(eachMenu))
            print ('# of error : {}'.format(error))
            MeterialEachDay.append('오류')
#     sys.stdout.write('\r'+str(date))
    menuKor['menuMeterial'].iloc[date] = MeterialEachDay
# Out:
# /Users/gimsuhyeon/Documents/shenv/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# error index : 4
# error menu : 닭불고기(180)
# # of error : 1
# error index : 5
# error menu : 동태매운탕(가공)
# # of error : 2
# error index : 6
# error menu : 깍두기(손칼)
# # of error : 3
# error index : 12
# error menu : 동태무조림(가공)
# # of error : 4
# error index : 12
# error menu : 시금치나물(90)
# # of error : 5
# error index : 14
# error menu : 깍두기(손칼)
# # of error : 6
# error index : 15
# error menu : 닭파인애플조림(토막)
# # of error : 7
# error index : 16
# error menu : 쌀밥(사무직)
# # of error : 8
# error index : 17
# error menu : 잡채(생선묵):연
# # of error : 9
# error index : 18
# error menu : 깍두기(손칼)
# # of error : 10
# error index : 20
# error menu : 콩가루배추국(단배추)-사용불가
# # of error : 11
# error index : 21
# error menu : 짬뽕밥(가공)
# # of error : 12
# error index : 22
# error menu : 깍두기(손칼)
# # of error : 13
# error index : 23
# error menu : 다시마채무침(무)
# # of error : 14
# error index : 24
# error menu : 깍두기(손칼)
# # of error : 15
# error index : 24
# error menu : 해장국(목뼈)
# # of error : 16
# error index : 28
# error menu : 오렌지(반)
# # of error : 17
# error index : 29
# error menu : 다시마채무침(무)
# # of error : 18
# error index : 29
# error menu : 포기김치2
# # of error : 19
# error index : 30
# error menu : 쌀밥(사무직)
# # of error : 20
# error index : 30
# error menu : 포기김치2
# # of error : 21
# error index : 31
# error menu : 포기김치2
# # of error : 22
# error index : 32
# error menu : 포기김치2
# # of error : 23
# error index : 33
# error menu : 깍두기(손칼)
# # of error : 24
# error index : 34
# error menu : 포기김치2
# # of error : 25
# error index : 35
# error menu : 포기김치2
# # of error : 26
# error index : 36
# error menu : 포기김치2
# # of error : 27
# error index : 37
# error menu : 쌀밥(사무직)
# # of error : 28
# error index : 37
# error menu : 포기김치2
# # of error : 29
# error index : 38
# error menu : 닭파인애플조림(토막)
# # of error : 30
# error index : 38
# error menu : 포기김치2
# # of error : 31
# error index : 39
# error menu : 쇠고기콩나물국1
# # of error : 32
# error index : 39
# error menu : 포기김치2
# # of error : 33
# error index : 40
# error menu : 포기김치2
# # of error : 34
# error index : 41
# error menu : 포기김치2
# # of error : 35
# error index : 42
# error menu : 깍두기(손칼)
# # of error : 36
# error index : 42
# error menu : 닭조림(토막)
# # of error : 37
# error index : 43
# error menu : 포기김치2
# # of error : 38
# error index : 45
# error menu : 포기김치2
# # of error : 39
# error index : 46
# error menu : 야채튀김(쑥갓)
# # of error : 40
# error index : 46
# error menu : 포기김치2
# # of error : 41
# error index : 47
# error menu : 포기김치2
# # of error : 42
# error index : 48
# error menu : 포기김치2
# # of error : 43
# error index : 49
# error menu : 콩가루배추국(단배추)-사용불가
# # of error : 44
# error index : 49
# error menu : 포기김치2
# # of error : 45
# error index : 50
# error menu : 닭불고기(180)
# # of error : 46
# error index : 50
# error menu : 포기김치2
# # of error : 47
# error index : 52
# error menu : 깍두기(손칼)
# # of error : 48
# error index : 53
# error menu : 포기김치2
# # of error : 49
# error index : 54
# error menu : 포기김치2
# # of error : 50
# error index : 55
# error menu : 포기김치2
# # of error : 51
# error index : 56
# error menu : 포기김치2
# # of error : 52
# error index : 57
# error menu : 포기김치2
# # of error : 53
# error index : 59
# error menu : 시금치나물(90)
# # of error : 54
# error index : 59
# error menu : 포기김치2
# # of error : 55
# error index : 60
# error menu : 포기김치2
# # of error : 56
# error index : 61
# error menu : 깍두기(손칼)
# # of error : 57
# error index : 62
# error menu : 포기김치2
# # of error : 58
# error index : 63
# error menu : 야채튀김(쑥갓)
# # of error : 59
# error index : 63
# error menu : 포기김치2
# # of error : 60
# error index : 64
# error menu : 포기김치2
# # of error : 61
# error index : 65
# error menu : 포기김치2
# # of error : 62
# error index : 66
# error menu : 깍두기(손칼)
# # of error : 63
# error index : 67
# error menu : 깍두기(손칼)
# # of error : 64
# error index : 68
# error menu : 대구지리(가공)
# # of error : 65
# error index : 68
# error menu : 미숫가루2
# # of error : 66
# error index : 68
# error menu : 포기김치2
# # of error : 67
# error index : 69
# error menu : 포기김치2
# # of error : 68
# error index : 70
# error menu : 포기김치2
# # of error : 69
# error index : 72
# error menu : 잡채(돈육)
# # of error : 70
# error index : 72
# error menu : 참외(썰어서)
# # of error : 71
# error index : 72
# error menu : 포기김치2
# # of error : 72
# error index : 73
# error menu : 포기김치2
# # of error : 73
# error index : 74
# error menu : 포기김치2
# # of error : 74
# error index : 75
# error menu : 닭파인애플조림(토막)
# # of error : 75
# error index : 75
# error menu : 미숫가루2
# # of error : 76
# error index : 75
# error menu : 잔파생채(70)
# # of error : 77
# error index : 76
# error menu : 동태무조림(가공)
# # of error : 78
# error index : 76
# error menu : 포기김치2
# # of error : 79
# error index : 77
# error menu : 깍두기(손칼)
# # of error : 80
# error index : 78
# error menu : 오렌지(반)
# # of error : 81
# error index : 78
# error menu : 포기김치2
# # of error : 82
# error index : 79
# error menu : 대구지리(가공)
# # of error : 83
# error index : 79
# error menu : 잔파생채(70)
# # of error : 84
# error index : 79
# error menu : 포기김치2
# # of error : 85
# error index : 80
# error menu : 포기김치2
# # of error : 86
# error index : 82
# error menu : 감자탕1
# # of error : 87
# error index : 82
# error menu : 오렌지(반)
# # of error : 88
# error index : 83
# error menu : 닭파인애플조림(토막)
# # of error : 89
# error index : 85
# error menu : 닭불고기(180)
# # of error : 90
# error index : 85
# error menu : 짬뽕국1
# # of error : 91
# error index : 85
# error menu : 포기김치2
# # of error : 92
# error index : 86
# error menu : 야채튀김(쑥갓)
# # of error : 93
# error index : 86
# error menu : 포기김치2
# # of error : 94
# error index : 87
# error menu : 잡채(돈육)
# # of error : 95
# error index : 87
# error menu : 포기김치2
# # of error : 96
# error index : 88
# error menu : 동태무조림(가공)
# # of error : 97
# error index : 88
# error menu : 포기김치2
# # of error : 98
# error index : 89
# error menu : 미숫가루2
# # of error : 99
# error index : 89
# error menu : 포기김치2
# # of error : 100
# error index : 90
# error menu : 삼겹살구이1
# # of error : 101
# error index : 90
# error menu : 콩가루배추국(단배추)-사용불가
# # of error : 102
# error index : 90
# error menu : 포기김치2
# # of error : 103
# error index : 91
# error menu : 닭조림(토막)
# # of error : 104
# error index : 91
# error menu : 쌀밥(사무직)
# # of error : 105
# error index : 92
# error menu : 포기김치2
# # of error : 106
# error index : 93
# error menu : 포기김치2
# # of error : 107
# error index : 95
# error menu : 깍두기(손칼)
# # of error : 108
# error index : 96
# error menu : 깍두기(손칼)
# # of error : 109
# error index : 97
# error menu : 쌀밥(사무직)
# # of error : 110
# error index : 97
# error menu : 한방닭백숙(반마리)
# # of error : 111
# error index : 98
# error menu : 미숫가루2
# # of error : 112
# error index : 98
# error menu : 포기김치2
# # of error : 113
# error index : 99
# error menu : 쌀밥(사무직)
# # of error : 114
# error index : 99
# error menu : 포기김치2
# # of error : 115
# error index : 101
# error menu : 오렌지(반)
# # of error : 116
# error index : 102
# error menu : 포기김치2
# # of error : 117
# error index : 103
# error menu : 잔파생채(70)
# # of error : 118
# error index : 103
# error menu : 콩가루배추국(단배추)-사용불가
# # of error : 119
# error index : 103
# error menu : 포기김치2
# # of error : 120
# error index : 104
# error menu : 닭조림(토막)
# # of error : 121
# error index : 104
# error menu : 동태매운탕(가공)
# # of error : 122
# error index : 104
# error menu : 포기김치2
# # of error : 123
# error index : 105
# error menu : 쌀밥(반공기)
# # of error : 124
# error index : 105
# error menu : 포기김치2
# # of error : 125
# error index : 106
# error menu : 포기김치2
# # of error : 126
# error index : 107
# error menu : 닭파인애플조림(토막)
# # of error : 127
# error index : 107
# error menu : 포기김치2
# # of error : 128
# error index : 108
# error menu : 대구지리(가공)
# # of error : 129
# error index : 108
# error menu : 미숫가루2
# # of error : 130
# error index : 108
# error menu : 포기김치2
# # of error : 131
# error index : 111
# error menu : 포기김치2
# # of error : 132
# error index : 112
# error menu : 깍두기(손칼)
# # of error : 133
# error index : 112
# error menu : 쌀밥(반공기)
# # of error : 134
# error index : 113
# error menu : 오렌지쥬스(행)
# # of error : 135
# error index : 113
# error menu : 포기김치2
# # of error : 136
# error index : 114
# error menu : 포기김치2
# # of error : 137
# error index : 115
# error menu : 잡채(생선묵):연
# # of error : 138
# error index : 115
# error menu : 포기김치2
# # of error : 139
# error index : 116
# error menu : 깍두기(손칼)
# # of error : 140
# error index : 117
# error menu : 포기김치2
# # of error : 141
# error index : 118
# error menu : 미숫가루2
# # of error : 142
# error index : 118
# error menu : 야채튀김(쑥갓)
# # of error : 143
# error index : 118
# error menu : 잔파생채(70)
# # of error : 144
# error index : 119
# error menu : 쌀밥(반공기)
# # of error : 145
# error index : 119
# error menu : 포기김치2
# # of error : 146
# error index : 120
# error menu : 깍두기(손칼)
# # of error : 147
# error index : 121
# error menu : 포기김치2
# # of error : 148
# error index : 122
# error menu : 깍두기(손칼)
# # of error : 149
# error index : 122
# error menu : 콩가루배추국(단배추)-사용불가
# # of error : 150
# error index : 123
# error menu : 포기김치2
# # of error : 151
# error index : 124
# error menu : 잡채(생선묵):연
# # of error : 152
# error index : 124
# error menu : 조기구이(사용불가)
# # of error : 153
# error index : 125
# error menu : 깍두기(손칼)
# # of error : 154
# error index : 126
# error menu : 포기김치2
# # of error : 155
# error index : 127
# error menu : 포기김치2
# # of error : 156
# error index : 129
# error menu : 닭파인애플조림(토막)
# # of error : 157
# error index : 129
# error menu : 포기김치2
# # of error : 158
# error index : 130
# error menu : 포기김치2
# # of error : 159
# error index : 132
# error menu : 대구지리(가공)
# # of error : 160
# error index : 132
# error menu : 야채튀김(쑥갓)
# # of error : 161
# error index : 132
# error menu : 포기김치2
# # of error : 162
# error index : 133
# error menu : 콩가루배추국(단배추)-사용불가
# # of error : 163
# error index : 133
# error menu : 포기김치2
# # of error : 164
# error index : 134
# error menu : 닭조림(토막)
# # of error : 165
# error index : 134
# error menu : 쌀밥(반공기)
# # of error : 166
# error index : 134
# error menu : 포기김치2
# # of error : 167
# error index : 135
# error menu : 시금치나물(90)
# # of error : 168
# error index : 135
# error menu : 오렌지(반)
# # of error : 169
# error index : 135
# error menu : 콩나물밥2
# # of error : 170
# error index : 135
# error menu : 포기김치2
# # of error : 171
# error index : 136
# error menu : 포기김치2
# # of error : 172
# error index : 136
# error menu : 호박죽(소)
# # of error : 173
# error index : 137
# error menu : 포기김치2
# # of error : 174
# error index : 139
# error menu : 닭조림(토막)
# # of error : 175
# error index : 139
# error menu : 순대국밥1
# # of error : 176
# error index : 140
# error menu : 쌀밥(반공기)
# # of error : 177
# error index : 141
# error menu : 포기김치2
# # of error : 178
# error index : 142
# error menu : 깍두기(손칼)
# # of error : 179
# error index : 143
# error menu : 포기김치2
# # of error : 180
# error index : 144
# error menu : 깍두기(손칼)
# # of error : 181
# error index : 144
# error menu : 닭조림(토막)
# # of error : 182
# error index : 144
# error menu : 콩가루배추국(단배추)-사용불가
# # of error : 183
# error index : 145
# error menu : 꽁치소금구이2
# # of error : 184
# error index : 145
# error menu : 포기김치2
# # of error : 185
# error index : 146
# error menu : 포기김치2
# # of error : 186
# error index : 147
# error menu : 시금치나물(90)
# # of error : 187
# error index : 147
# error menu : 포기김치2
# # of error : 188
# error index : 148
# error menu : 포기김치2
# # of error : 189
# error index : 149
# error menu : 포기김치2
# # of error : 190
# error index : 150
# error menu : 잡채(돈육)
# # of error : 191
# error index : 150
# error menu : 포기김치2
# # of error : 192
# error index : 152
# error menu : 포기김치2
# # of error : 193
# error index : 153
# error menu : 깍두기(손칼)
# # of error : 194
# error index : 154
# error menu : 닭조림(토막)
# # of error : 195
# error index : 154
# error menu : 쌀밥(반공기)
# # of error : 196
# error index : 154
# error menu : 포기김치2
# # of error : 197
# error index : 155
# error menu : 대구지리(가공)
# # of error : 198
# error index : 156
# error menu : 콩나물밥2
# # of error : 199
# error index : 156
# error menu : 포기김치2
# # of error : 200
# error index : 157
# error menu : 닭파인애플조림(토막)
# # of error : 201
# error index : 157
# error menu : 미숫가루2
# # of error : 202
# error index : 157
# error menu : 포기김치2
# # of error : 203
# error index : 158
# error menu : 포기김치2
# # of error : 204
# error index : 159
# error menu : 포기김치2
# # of error : 205
# error index : 160
# error menu : 깍두기(손칼)
# # of error : 206
# error index : 160
# error menu : 호박죽(소)
# # of error : 207
# error index : 161
# error menu : 쌀밥(반공기)
# # of error : 208
# error index : 162
# error menu : 포기김치2
# # of error : 209
# error index : 163
# error menu : 깍두기(손칼)
# # of error : 210
# error index : 163
# error menu : 잔파생채(70)
# # of error : 211
# error index : 164
# error menu : 포기김치2
# # of error : 212
# error index : 165
# error menu : 꽁치소금구이2
# # of error : 213
# error index : 165
# error menu : 잡채(생선묵):연
# # of error : 214
# error index : 165
# error menu : 포기김치2
# # of error : 215
# error index : 166
# error menu : 깍두기(손칼)
# # of error : 216
# error index : 166
# error menu : 닭조림(토막)
# # of error : 217
# error index : 167
# error menu : 포기김치2
# # of error : 218
# error index : 168
# error menu : 쌀밥(반공기)
# # of error : 219
# error index : 168
# error menu : 포기김치2
# # of error : 220
# error index : 169
# error menu : 깍두기(손칼)
# # of error : 221
# error index : 173
# error menu : 육개장(사골)2
# # of error : 222
# error index : 174
# error menu : 꽁치소금구이2
# # of error : 223
# error index : 175
# error menu : 쌀밥(반공기)
# # of error : 224
# error index : 176
# error menu : 오렌지(반)
# # of error : 225
# error index : 177
# error menu : 닭조림(토막)
# # of error : 226
# error index : 177
# error menu : 동태매운탕(가공)
# # of error : 227
# error index : 177
# error menu : 연두부양념장(반모)
# # of error : 228
# error index : 178
# error menu : 야채튀김(쑥갓)
# # of error : 229
# error index : 179
# error menu : 오렌지(반)
# # of error : 230
# error index : 179
# error menu : 콩가루배추국(단배추)-사용불가
# # of error : 231
# error index : 182
# error menu : 해장국(목뼈)
# # of error : 232
# error index : 183
# error menu : 쌀밥(반공기)
# # of error : 233
# error index : 183
# error menu : 크림스프(경양식)
# # of error : 234
# error index : 185
# error menu : 한방닭백숙(반마리)
# # of error : 235
# error index : 186
# error menu : 북어포고추장무침2
# # of error : 236
# error index : 186
# error menu : 잡채(생선묵):연
# # of error : 237
# error index : 188
# error menu : 깍두기(손칼)
# # of error : 238
# error index : 195
# error menu : 깍두기(손칼)
# # of error : 239
# error index : 195
# error menu : 낙지덮밥1
# # of error : 240
# error index : 197
# error menu : 동태매운탕(가공)
# # of error : 241
# error index : 198
# error menu : 해장국(목뼈)
# # of error : 242
# error index : 199
# error menu : 오렌지(반)
# # of error : 243
# error index : 200
# error menu : 호박죽(소)
# # of error : 244
# error index : 204
# error menu : 쌀밥(반공기)
# # of error : 245
# error index : 204
# error menu : 야채튀김(쑥갓)
# # of error : 246
# error index : 205
# error menu : 꽁치소금구이2
# # of error : 247
# error index : 214
# error menu : 삼겹살구이1
# # of error : 248
# error index : 216
# error menu : 깍두기(손칼)
# # of error : 249
# error index : 220
# error menu : 후라이드치킨(토막)
# # of error : 250
# error index : 223
# error menu : 쌀밥(반공기)
# # of error : 251
# error index : 227
# error menu : 오렌지(반)
# # of error : 252
# error index : 228
# error menu : 북어포고추장무침2
# # of error : 253
# error index : 229
# error menu : 딸기잼(1회용)
# # of error : 254
# error index : 229
# error menu : 쌀밥(반공기)
# # of error : 255
# error index : 230
# error menu : 깍두기(손칼)
# # of error : 256
# error index : 230
# error menu : 쌀밥(반공기)
# # of error : 257
# error index : 231
# error menu : 해장국(목뼈)
# # of error : 258
# error index : 232
# error menu : 양념통닭(토막)
# # of error : 259
# error index : 233
# error menu : 호박죽(소)
# # of error : 260
# error index : 235
# error menu : 깍두기(손칼)
# # of error : 261
# error index : 235
# error menu : 연두부양념장(반모)
# # of error : 262
# error index : 237
# error menu : 야채튀김(쑥갓)
# # of error : 263
# error index : 239
# error menu : 꽁치소금구이2
# # of error : 264
# error index : 240
# error menu : 오렌지(반)
# # of error : 265
# error index : 241
# error menu : 잡채(생선묵):연
# # of error : 266
# error index : 242
# error menu : 깍두기(손칼)
# # of error : 267
# error index : 244
# error menu : 삼겹살구이1
# # of error : 268
# error index : 245
# error menu : 닭불고기(180)
# # of error : 269
# error index : 247
# error menu : 삼겹살구이1
# # of error : 270
# error index : 249
# error menu : 오렌지(반)
# # of error : 271
# error index : 253
# error menu : 깍두기(손칼)
# # of error : 272
# error index : 255
# error menu : 딸기잼(1회용)
# # of error : 273
# error index : 257
# error menu : 쌀밥(찹쌀)
# # of error : 274
# error index : 257
# error menu : 아구찜(B)
# # of error : 275
# error index : 259
# error menu : 쌀밥(반공기)
# # of error : 276
# error index : 262
# error menu : 대구지리(가공)
# # of error : 277
# error index : 264
# error menu : 깍두기(손칼)
# # of error : 278
# error index : 269
# error menu : 야채튀김(쑥갓)
# # of error : 279
# error index : 272
# error menu : 호박죽(소)
# # of error : 280
# error index : 281
# error menu : 대구지리(가공)
# # of error : 281
# error index : 281
# error menu : 오렌지(반)
# # of error : 282
# error index : 281
# error menu : 잡채(생선묵):연
# # of error : 283
# error index : 286
# error menu : 쌀밥(반공기)
# # of error : 284
# error index : 287
# error menu : 깍두기(손칼)
# # of error : 285
# error index : 290
# error menu : 깍두기(손칼)
# # of error : 286
# error index : 290
# error menu : 쌀밥(반공기)
# # of error : 287
# error index : 292
# error menu : 동태매운탕(가공)
# # of error : 288
# error index : 294
# error menu : 오렌지(반)
# # of error : 289
# error index : 295
# error menu : 해장국(목뼈)
# # of error : 290
# error index : 297
# error menu : 쌀밥(반공기)
# # of error : 291
# error index : 298
# error menu : 쌀밥(찹쌀)
# # of error : 292
# error index : 298
# error menu : 자반고등어찜2
# # of error : 293
# error index : 298
# error menu : 파강회(B)
# # of error : 294
# error index : 298
# error menu : 파인애플(1조각)
# # of error : 295
# error index : 298
# error menu : 한방닭백숙(반마리)
# # of error : 296
# error index : 301
# error menu : 오렌지(반)
# # of error : 297
# error index : 302
# error menu : 자반고등어찜2
# # of error : 298
# error index : 312
# error menu : 오렌지(반)
# # of error : 299
# error index : 319
# error menu : 오렌지(반)
# # of error : 300
# error index : 321
# error menu : 삼겹살구이1
# # of error : 301
# error index : 325
# error menu : 카레라이스(양송이캔)
# # of error : 302
# error index : 326
# error menu : 가자미무조림(가공)
# # of error : 303
# error index : 326
# error menu : 잡채(생선묵):연
# # of error : 304
# error index : 332
# error menu : 쌀밥(반공기)
# # of error : 305
# error index : 334
# error menu : 잡채(생선묵):연
# # of error : 306
# error index : 335
# error menu : 잡채(생선묵):연
# # of error : 307
# error index : 339
# error menu : 깍두기(손칼)
# # of error : 308
# error index : 340
# error menu : 고구마순볶음(포)
# # of error : 309
# error index : 347
# error menu : 자반고등어찜2
# # of error : 310
# error index : 353
# error menu : 쌀밥(반공기)
# # of error : 311
# error index : 355
# error menu : 잡채(생선묵):연
# # of error : 312
# error index : 369
# error menu : 잡채(생선묵):연
# # of error : 313
# error index : 372
# error menu : 닭조림(토막)
# # of error : 314
# error index : 374
# error menu : 냉잔치국수(콩나물)
# # of error : 315
# error index : 375
# error menu : 딸기잼(1회용)
# # of error : 316
# error index : 375
# error menu : 쌀밥(반공기)
# # of error : 317
# error index : 376
# error menu : 잡채(생선묵):연
# # of error : 318
# error index : 378
# error menu : 쌀밥(반공기)
# # of error : 319
# error index : 378
# error menu : 한방닭백숙(반마리)
# # of error : 320
# error index : 379
# error menu : 삼겹살구이1
# # of error : 321
# error index : 381
# error menu : 비빔밥(표고)
# # of error : 322
# error index : 385
# error menu : 잡채(생선묵):연
# # of error : 323
# error index : 388
# error menu : 한방닭백숙(반마리)
# # of error : 324
# error index : 390
# error menu : 꽁치소금구이2
# # of error : 325
# error index : 392
# error menu : 꽁치소금구이2
# # of error : 326
# error index : 395
# error menu : 잡채(생선묵):연
# # of error : 327
# error index : 398
# error menu : 한방닭백숙(반마리)
# # of error : 328
# error index : 402
# error menu : 양념통닭(토막)
# # of error : 329
# error index : 405
# error menu : 꽁치소금구이2
# # of error : 330
# error index : 406
# error menu : 닭조림(토막)
# # of error : 331
# error index : 406
# error menu : 잡채(생선묵):연
# # of error : 332
# error index : 409
# error menu : 깍두기(손칼)
# # of error : 333
# error index : 410
# error menu : 깍두기(손칼)
# # of error : 334
# error index : 412
# error menu : 깍두기(손칼)
# # of error : 335
# error index : 414
# error menu : 닭조림(토막)
# # of error : 336
# error index : 415
# error menu : 곰탕1
# # of error : 337
# error index : 417
# error menu : 쌀밥(반공기)
# # of error : 338
# error index : 419
# error menu : 호박죽(소)
# # of error : 339
# error index : 421
# error menu : 삼겹살구이1
# # of error : 340
# error index : 422
# error menu : 한방닭백숙(반마리)
# # of error : 341
# error index : 423
# error menu : 깍두기(손칼)
# # of error : 342
# error index : 426
# error menu : 닭조림(토막)
# # of error : 343
# error index : 427
# error menu : 깍두기(손칼)
# # of error : 344
# error index : 429
# error menu : 꽁치소금구이2
# # of error : 345
# error index : 429
# error menu : 잡채(생선묵):연
# # of error : 346
# error index : 432
# error menu : 꽈리고추멸치볶음(잔멸치)
# # of error : 347
# error index : 435
# error menu : 소머리곰탕(중식당)
# # of error : 348
# error index : 436
# error menu : 쌀밥(반공기)
# # of error : 349
# error index : 438
# error menu : 잡채(생선묵):연
# # of error : 350
# error index : 439
# error menu : 닭조림(토막)
# # of error : 351
# error index : 440
# error menu : 육개장(사골)2
# # of error : 352
# error index : 440
# error menu : 호박죽(소)
# # of error : 353
# error index : 443
# error menu : 잔파생채(70)
# # of error : 354
# error index : 443
# error menu : 카레라이스(양송이캔)
# # of error : 355
# error index : 445
# error menu : 꽁치소금구이2
# # of error : 356
# error index : 446
# error menu : 닭조림(토막)
# # of error : 357
# error index : 455
# error menu : 소머리곰탕(중식당)
# # of error : 358
# error index : 457
# error menu : 꽁치소금구이2
# # of error : 359
# error index : 462
# error menu : 만두국1
# # of error : 360
# error index : 463
# error menu : 호박죽(소)
# # of error : 361
# error index : 469
# error menu : 깍두기(손칼)
# # of error : 362
# error index : 469
# error menu : 꽁치소금구이2
# # of error : 363
# error index : 470
# error menu : 삼겹살구이1
# # of error : 364
# error index : 472
# error menu : 잡채(돈육)
# # of error : 365
# error index : 477
# error menu : 육개장(사골)2
# # of error : 366
# error index : 480
# error menu : 잡채(생선묵):연
# # of error : 367
# error index : 483
# error menu : 닭조림(토막)
# # of error : 368
# error index : 488
# error menu : 호박죽(소)
# # of error : 369
# error index : 489
# error menu : 깍두기(손칼)
# # of error : 370
# error index : 490
# error menu : 잡채(생선묵):연
# # of error : 371
# error index : 494
# error menu : 감자튀김(경양식)
# # of error : 372
# error index : 494
# error menu : 크림스프(경양식)
# # of error : 373
# error index : 496
# error menu : 닭파인애플조림(토막)
# # of error : 374
# error index : 500
# error menu : 꽁치소금구이2
# # of error : 375
# error index : 502
# error menu : 삼겹살구이1
# # of error : 376
# error index : 504
# error menu : 순대야채볶음(70g)
# # of error : 377
# error index : 504
# error menu : 호박죽(소)
# # of error : 378
# error index : 507
# error menu : 감자튀김(경양식)
# # of error : 379
# error index : 507
# error menu : 크림스프(경양식)
# # of error : 380
# error index : 510
# error menu : 잔파생채(70)
# # of error : 381
# error index : 513
# error menu : 꽁치소금구이2
# # of error : 382
# error index : 515
# error menu : 잡채(생선묵):연
# # of error : 383
# error index : 519
# error menu : 삼겹살구이2
# # of error : 384
# error index : 520
# error menu : 쌀밥(반공기)
# # of error : 385
# error index : 524
# error menu : 해장국(목뼈)
# # of error : 386
# error index : 525
# error menu : 우엉콩조림(흰콩)
# # of error : 387
# error index : 526
# error menu : 잡채(생선묵):연
# # of error : 388
# error index : 528
# error menu : 순대야채볶음(70g)
# # of error : 389
# error index : 528
# error menu : 호박죽(소)
# # of error : 390
# error index : 530
# error menu : 꽁치소금구이2
# # of error : 391
# error index : 531
# error menu : 잡채(생선묵):연
# # of error : 392
# error index : 533
# error menu : 한방닭백숙(반마리)
# # of error : 393
# error index : 535
# error menu : 크림스프(경양식)
# # of error : 394
# error index : 543
# error menu : 꽁치소금구이2
# # of error : 395
# error index : 544
# error menu : 잡채(생선묵):연
# # of error : 396
# error index : 548
# error menu : 잡채(생선묵):연
# # of error : 397
# error index : 551
# error menu : 호박죽(소)
# # of error : 398
# error index : 555
# error menu : 꽁치소금구이2
# # of error : 399
# error index : 555
# error menu : 순대야채볶음(70g)
# # of error : 400
# error index : 557
# error menu : 쌀밥(반공기)
# # of error : 401
# error index : 563
# error menu : 쌀밥(반공기)
# # of error : 402
# error index : 564
# error menu : 삼겹살구이1
# # of error : 403
# error index : 565
# error menu : 쌀밥(반공기)
# # of error : 404
# error index : 565
# error menu : 한방닭백숙(반마리)
# # of error : 405
# error index : 568
# error menu : 호박죽(소)
# # of error : 406
# error index : 569
# error menu : 잡채(생선묵):연
# # of error : 407
# error index : 572
# error menu : 야채튀김(쑥갓)
# # of error : 408
# error index : 573
# error menu : 자반고등어찜2
# # of error : 409
# error index : 574
# error menu : 꽁치소금구이2
# # of error : 410
# error index : 578
# error menu : 닭파인애플조림(토막)
# # of error : 411
# error index : 581
# error menu : 꽁치소금구이2
# # of error : 412
# error index : 585
# error menu : 크림스프(경양식)
# # of error : 413
# error index : 590
# error menu : 한방닭백숙(반마리)
# # of error : 414
# error index : 591
# error menu : 순대야채볶음(70g)
# # of error : 415
# error index : 593
# error menu : 깍두기(손칼)
# # of error : 416
# error index : 595
# error menu : 잡채(생선묵):연
# # of error : 417
# error index : 598
# error menu : 닭조림(토막)
# # of error : 418
# error index : 599
# error menu : 삼겹살구이2
# # of error : 419
# error index : 600
# error menu : 깍두기(손칼)
# # of error : 420
# error index : 601
# error menu : 호박죽(소)
# # of error : 421
# error index : 603
# error menu : 깍두기(손칼)
# # of error : 422
# error index : 605
# error menu : 꽁치소금구이2
# # of error : 423
# error index : 606
# error menu : 깍두기(손칼)
# # of error : 424
# error index : 608
# error menu : 양미리조림(U)
# # of error : 425
# error index : 609
# error menu : 깍두기(손칼)
# # of error : 426
# error index : 610
# error menu : 봄나물비빔밥2
# # of error : 427
# error index : 611
# error menu : 호박죽(소)
# # of error : 428
# error index : 613
# error menu : 잡채(생선묵):연
# # of error : 429
# error index : 615
# error menu : 계피차(K)
# # of error : 430
# error index : 615
# error menu : 순대야채볶음(70g)
# # of error : 431
# error index : 616
# error menu : 닭조림(토막)
# # of error : 432
# error index : 617
# error menu : 새우젓무침(K)
# # of error : 433
# error index : 619
# error menu : 깍두기(손칼)
# # of error : 434
# error index : 620
# error menu : 소방어무조림(가공)
# # of error : 435
# error index : 621
# error menu : 깍두기(손칼)
# # of error : 436
# error index : 622
# error menu : 연두부양념장(반모)
# # of error : 437
# error index : 623
# error menu : 깍두기(손칼)
# # of error : 438
# error index : 626
# error menu : 야채튀김(쑥갓)
# # of error : 439
# error index : 630
# error menu : 꽁치소금구이2
# # of error : 440
# error index : 635
# error menu : 야채튀김(쑥갓)
# # of error : 441
# error index : 636
# error menu : 깍두기(손칼)
# # of error : 442
# error index : 636
# error menu : 미숫가루2
# # of error : 443
# error index : 641
# error menu : 소방어무조림(가공)
# # of error : 444
# error index : 642
# error menu : 깍두기(손칼)
# # of error : 445
# error index : 643
# error menu : 잡채(생선묵):연
# # of error : 446
# error index : 644
# error menu : 깍두기(손칼)
# # of error : 447
# error index : 644
# error menu : 한방닭백숙(반마리)
# # of error : 448
# error index : 645
# error menu : 꽁치소금구이2
# # of error : 449
# error index : 646
# error menu : 쌀밥(반공기)
# # of error : 450
# error index : 647
# error menu : 깍두기(손칼)
# # of error : 451
# error index : 647
# error menu : 미숫가루2
# # of error : 452
# error index : 648
# error menu : 오렌지(반)
# # of error : 453
# error index : 650
# error menu : 순두부백탕&양념장
# # of error : 454
# error index : 651
# error menu : 호박죽(소)
# # of error : 455
# error index : 653
# error menu : 후라이드치킨(토막)
# # of error : 456
# error index : 654
# error menu : 미숫가루2
# # of error : 457
# error index : 657
# error menu : 잡채(생선묵):연
# # of error : 458
# error index : 659
# error menu : 미숫가루2
# # of error : 459
# error index : 660
# error menu : 깍두기(손칼)
# # of error : 460
# error index : 660
# error menu : 해장국(목뼈)
# # of error : 461
# error index : 662
# error menu : 깍두기(손칼)
# # of error : 462
# error index : 662
# error menu : 꽁치소금구이2
# # of error : 463
# error index : 663
# error menu : 보쌈김치(K)
# # of error : 464
# error index : 663
# error menu : 여러가지야채2
# # of error : 465
# error index : 665
# error menu : 닭파인애플조림(토막)
# # of error : 466
# error index : 667
# error menu : 크림스프(경양식)
# # of error : 467
# error index : 668
# error menu : 깍두기(손칼)
# # of error : 468
# error index : 674
# error menu : 짬뽕밥2
# # of error : 469
# error index : 677
# error menu : 소방어무조림(가공)
# # of error : 470
# error index : 678
# error menu : 삼겹살구이2
# # of error : 471
# error index : 679
# error menu : 깍두기(손칼)
# # of error : 472
# error index : 681
# error menu : 닭조림(토막)
# # of error : 473
# error index : 686
# error menu : 미숫가루2
# # of error : 474
# error index : 688
# error menu : 깍두기(손칼)
# # of error : 475
# error index : 688
# error menu : 순대야채볶음(70g)
# # of error : 476
# error index : 691
# error menu : 닭조림(토막)
# # of error : 477
# error index : 691
# error menu : 연두부양념장(반모)
# # of error : 478
# error index : 693
# error menu : 우엉콩조림(흰콩)
# # of error : 479
# error index : 695
# error menu : 북어미역국(K)
# # of error : 480
# error index : 699
# error menu : 깍두기(손칼)
# # of error : 481
# error index : 699
# error menu : 미숫가루2
# # of error : 482
# error index : 700
# error menu : 쌀밥(반공기)
# # of error : 483
# error index : 704
# error menu : 깍두기(손칼)
# # of error : 484
# error index : 704
# error menu : 삼치구이&데리야끼소스
# # of error : 485
# error index : 705
# error menu : 잡채(어묵)
# # of error : 486
# error index : 712
# error menu : 삼겹살구이1
# # of error : 487
# error index : 713
# error menu : 무생채(잔파)
# # of error : 488
# error index : 713
# error menu : 자반고등어찜2
# # of error : 489
# error index : 719
# error menu : 자반고등어찜2
# # of error : 490
# error index : 722
# error menu : 쌀밥(반공기)
# # of error : 491
# error index : 724
# error menu : 깍두기(손칼)
# # of error : 492
# error index : 726
# error menu : 무채국(콩가루)
# # of error : 493
# error index : 727
# error menu : 깍두기(손칼)
# # of error : 494
# error index : 731
# error menu : 잡채(어묵)
# # of error : 495
# error index : 733
# error menu : 깍두기(손칼)
# # of error : 496
# error index : 734
# error menu : 생선까스&타르
# # of error : 497
# error index : 735
# error menu : 깍두기(손칼)
# # of error : 498
# error index : 738
# error menu : 자반고등어찜2
# # of error : 499
# error index : 739
# error menu : 깍두기(손칼)
# # of error : 500
# error index : 743
# error menu : 무생채(잔파)
# # of error : 501
# error index : 745
# error menu : 깍두기(손칼)
# # of error : 502
# error index : 748
# error menu : 비빔밥(표고)
# # of error : 503
# error index : 750
# error menu : 오곡밥2
# # of error : 504
# error index : 754
# error menu : 닭조림(토막)
# # of error : 505
# error index : 755
# error menu : 깍두기(손칼)
# # of error : 506
# error index : 755
# error menu : 해장국(목뼈)
# # of error : 507
# error index : 757
# error menu : 깍두기(손칼)
# # of error : 508
# error index : 757
# error menu : 잡채(어묵)
# # of error : 509
# error index : 760
# error menu : 삼치구이&데리야끼소스
# # of error : 510
# error index : 761
# error menu : 깍두기(손칼)
# # of error : 511
# error index : 762
# error menu : 잡채(어묵)
# # of error : 512
# error index : 764
# error menu : 깍두기(손칼)
# # of error : 513
# error index : 765
# error menu : 깍두기(손칼)
# # of error : 514
# error index : 765
# error menu : 잔파생채(70)
# # of error : 515
# error index : 767
# error menu : 소방어무조림(가공)
# # of error : 516
# error index : 769
# error menu : 깍두기(손칼)
# # of error : 517
# error index : 770
# error menu : 자반고등어찜2
# # of error : 518
# error index : 771
# error menu : 오렌지(반)
# # of error : 519
# error index : 777
# error menu : 깍두기(손칼)
# # of error : 520
# error index : 780
# error menu : 오렌지(반)
# # of error : 521
# error index : 781
# error menu : 야채튀김(쑥갓)
# # of error : 522
# error index : 782
# error menu : 깍두기(손칼)
# # of error : 523
# error index : 785
# error menu : 미숫가루2
# # of error : 524
# error index : 786
# error menu : 자반고등어찜2
# # of error : 525
# error index : 791
# error menu : 자반고등어찜2
# # of error : 526
# error index : 794
# error menu : 닭불고기(180)
# # of error : 527
# error index : 794
# error menu : 삼치구이&데리야끼소스
# # of error : 528
# error index : 798
# error menu : 닭다리버터구이(토막)
# # of error : 529
# error index : 799
# error menu : 오렌지(반)
# # of error : 530
# error index : 801
# error menu : 미숫가루2
# # of error : 531
# error index : 801
# error menu : 자반고등어찜2
# # of error : 532
# error index : 804
# error menu : 잡채(어묵)
# # of error : 533
# error index : 806
# error menu : 깍두기(손칼)
# # of error : 534
# error index : 806
# error menu : 한방닭백숙(반마리)
# # of error : 535
# error index : 808
# error menu : 우엉콩조림(흰콩)
# # of error : 536
# error index : 810
# error menu : 자반고등어찜2
# # of error : 537
# error index : 813
# error menu : 미숫가루2
# # of error : 538
# error index : 814
# error menu : 오렌지(반)
# # of error : 539
# error index : 815
# error menu : 자반고등어찜2
# # of error : 540
# error index : 815
# error menu : 잡채(어묵)
# # of error : 541
# error index : 816
# error menu : 깍두기(손칼)
# # of error : 542
# error index : 819
# error menu : 쌀밥(반공기)
# # of error : 543
# error index : 821
# error menu : 무생채(잔파)
# # of error : 544
# error index : 822
# error menu : 미숫가루2
# # of error : 545
# error index : 826
# error menu : 깍두기(손칼)
# # of error : 546
# error index : 828
# error menu : 오렌지(반)
# # of error : 547
# error index : 829
# error menu : 자반고등어찜2
# # of error : 548
# error index : 831
# error menu : 오렌지(반)
# # of error : 549
# error index : 832
# error menu : 닭조림(토막)
# # of error : 550
# error index : 832
# error menu : 야채튀김(쑥갓)
# # of error : 551
# error index : 835
# error menu : 깍두기(손칼)
# # of error : 552
# error index : 835
# error menu : 삼치구이&데리야끼소스
# # of error : 553
# error index : 838
# error menu : 우엉콩조림(흑콩)
# # of error : 554
# error index : 841
# error menu : 자반고등어찜2
# # of error : 555
# error index : 843
# error menu : 잡채(어묵)
# # of error : 556
# error index : 846
# error menu : 삼치구이&데리야끼소스
# # of error : 557
# error index : 850
# error menu : 깍두기(손칼)
# # of error : 558
# error index : 852
# error menu : 잡채(어묵)
# # of error : 559
# error index : 857
# error menu : 미숫가루2
# # of error : 560
# error index : 859
# error menu : 깍두기(손칼)
# # of error : 561
# error index : 865
# error menu : 깍두기(손칼)
# # of error : 562
# error index : 865
# error menu : 자반고등어찜2
# # of error : 563
# error index : 865
# error menu : 잡채(어묵)
# # of error : 564
# error index : 870
# error menu : 삼치구이&데리야끼소스
# # of error : 565
# error index : 870
# error menu : 온두부&볶음김치
# # of error : 566
# error index : 874
# error menu : 깍두기(손칼)
# # of error : 567
# error index : 878
# error menu : 미숫가루2
# # of error : 568
# error index : 882
# error menu : 잡채(어묵)
# # of error : 569
# error index : 884
# error menu : 잡채(어묵)
# # of error : 570
# error index : 885
# error menu : 고구마순볶음(포)
# # of error : 571
# error index : 887
# error menu : 미숫가루2
# # of error : 572
# error index : 887
# error menu : 한방닭백숙(반마리)
# # of error : 573
# error index : 890
# error menu : 깍두기(손칼)
# # of error : 574
# error index : 892
# error menu : 깍두기(손칼)
# # of error : 575
# error index : 892
# error menu : 닭조림(토막)
# # of error : 576
# error index : 893
# error menu : 깍두기(손칼)
# # of error : 577
# error index : 895
# error menu : 깍두기(손칼)
# # of error : 578
# error index : 895
# error menu : 생선까스&타르
# # of error : 579
# error index : 895
# error menu : 오렌지(반)
# # of error : 580
# error index : 899
# error menu : 미숫가루2
# # of error : 581
# error index : 901
# error menu : 온두부&볶음김치
# # of error : 582
# error index : 903
# error menu : 자반고등어찜2
# # of error : 583
# error index : 903
# error menu : 잡채(어묵)
# # of error : 584
# error index : 904
# error menu : 생선까스&타르
# # of error : 585
# error index : 906
# error menu : 미숫가루2
# # of error : 586
# error index : 910
# error menu : 후라이드치킨(토막)
# # of error : 587
# error index : 912
# error menu : 삼치구이&데리야끼소스
# # of error : 588
# error index : 914
# error menu : 잡채(어묵)
# # of error : 589
# error index : 915
# error menu : 미숫가루2
# # of error : 590
# error index : 916
# error menu : 무생채(잔파)
# # of error : 591
# error index : 918
# error menu : 한방닭백숙(반마리)
# # of error : 592
# error index : 919
# error menu : 깍두기(손칼)
# # of error : 593
# error index : 920
# error menu : 무채국(콩가루)
# # of error : 594
# error index : 925
# error menu : 생선까스&타르
# # of error : 595
# error index : 926
# error menu : 미숫가루2
# # of error : 596
# error index : 934
# error menu : 미숫가루2
# # of error : 597
# error index : 934
# error menu : 잡채(어묵)
# # of error : 598
# error index : 937
# error menu : 깍두기(손칼)
# # of error : 599
# error index : 937
# error menu : 생선까스&타르
# # of error : 600
# error index : 938
# error menu : 무생채(잔파)
# # of error : 601
# error index : 942
# error menu : 미숫가루2
# # of error : 602
# error index : 943
# error menu : 삼겹살구이2
# # of error : 603
# error index : 943
# error menu : 여러가지야채&쌈장
# # of error : 604
# error index : 944
# error menu : 냉잔치국수(콩나물)
# # of error : 605
# error index : 944
# error menu : 쌀밥(반공기)
# # of error : 606
# error index : 946
# error menu : 자반고등어찜2
# # of error : 607
# error index : 947
# error menu : 미숫가루2
# # of error : 608
# error index : 949
# error menu : 삼치구이&데리야끼소스
# # of error : 609
# error index : 952
# error menu : 자반고등어찜2
# # of error : 610
# error index : 964
# error menu : 메론(I중)
# # of error : 611
# error index : 964
# error menu : 생선까스&타르
# # of error : 612
# error index : 968
# error menu : 무생채(잔파)
# # of error : 613
# error index : 977
# error menu : 깍두기(손칼)
# # of error : 614
# error index : 978
# error menu : 다시마채무침(무)
# # of error : 615
# error index : 983
# error menu : 깍두기(손칼)
# # of error : 616
# error index : 984
# error menu : 호박죽(소)
# # of error : 617
# error index : 987
# error menu : 자반고등어찜2
# # of error : 618
# error index : 989
# error menu : 깍두기(손칼)
# # of error : 619
# error index : 993
# error menu : 호박죽(소)
# # of error : 620
# error index : 994
# error menu : 양념통닭(토막)
# # of error : 621
# error index : 998
# error menu : 깍두기(손칼)
# # of error : 622
# error index : 1004
# error menu : 오렌지(반)
# # of error : 623
# error index : 1007
# error menu : 닭조림(토막)
# # of error : 624
# error index : 1008
# error menu : 깍두기(손칼)
# # of error : 625
# error index : 1008
# error menu : 자반고등어찜2
# # of error : 626
# error index : 1009
# error menu : 잡채(어묵)
# # of error : 627
# error index : 1011
# error menu : 잡채(어묵)
# # of error : 628
# error index : 1013
# error menu : 야채튀김(쑥갓)
# # of error : 629
# error index : 1015
# error menu : 깍두기(손칼)
# # of error : 630
# error index : 1016
# error menu : 옥수수고로케(천일)
# # of error : 631
# error index : 1017
# error menu : 잔파생채(70)
# # of error : 632
# error index : 1019
# error menu : 비빔밥(표고)
# # of error : 633
# error index : 1020
# error menu : 깍두기(손칼)
# # of error : 634
# error index : 1025
# error menu : 온두부&볶음김치
# # of error : 635
# error index : 1028
# error menu : 잡채(어묵)
# # of error : 636
# error index : 1033
# error menu : 깍두기(손칼)
# # of error : 637
# error index : 1033
# error menu : 아구탕(특)
# # of error : 638
# error index : 1034
# error menu : 닭조림(토막)
# # of error : 639
# error index : 1036
# error menu : 쌀밥(반공기)
# # of error : 640
# error index : 1036
# error menu : 후라이드치킨(토막)
# # of error : 641
# error index : 1039
# error menu : 삼치구이&데리야끼소스
# # of error : 642
# error index : 1042
# error menu : 깍두기(손칼)
# # of error : 643
# error index : 1042
# error menu : 해장국(목뼈)
# # of error : 644
# error index : 1043
# error menu : 무생채(잔파)
# # of error : 645
# error index : 1044
# error menu : 자반고등어찜2
# # of error : 646
# error index : 1047
# error menu : 깍두기(손칼)
# # of error : 647
# error index : 1049
# error menu : 온두부&볶음김치
# # of error : 648
# error index : 1054
# error menu : 깍두기(손칼)
# # of error : 649
# error index : 1056
# error menu : 깍두기(손칼)
# # of error : 650
# error index : 1058
# error menu : 삼겹살구이1
# # of error : 651
# error index : 1062
# error menu : 비빔밥(표고)
# # of error : 652
# error index : 1065
# error menu : 깍두기(손칼)
# # of error : 653
# error index : 1067
# error menu : 꼬지어묵탕1
# # of error : 654
# error index : 1067
# error menu : 무생채(잔파)
# # of error : 655
# error index : 1068
# error menu : 잡채(어묵)
# # of error : 656
# error index : 1069
# error menu : 깍두기(손칼)
# # of error : 657
# error index : 1075
# error menu : 깍두기(손칼)
# # of error : 658
# error index : 1077
# error menu : 야채튀김(쑥갓)
# # of error : 659
# error index : 1078
# error menu : 깍두기(손칼)
# # of error : 660
# error index : 1079
# error menu : 온두부&볶음김치
# # of error : 661
# error index : 1080
# error menu : 옥수수고로케(천일)
# # of error : 662
# error index : 1085
# error menu : 삼겹살구이1
# # of error : 663
# error index : 1086
# error menu : 삼치구이&데리야끼소스
# # of error : 664
# error index : 1087
# error menu : 깍두기(손칼)
# # of error : 665
# error index : 1087
# error menu : 순대국밥(뼈)
# # of error : 666
# error index : 1092
# error menu : 쌀밥(반공기)
# # of error : 667
# error index : 1092
# error menu : 야채튀김(쑥갓)
# # of error : 668
# error index : 1096
# error menu : 삼치구이&데리야끼소스
# # of error : 669
# error index : 1097
# error menu : 깍두기(손칼)
# # of error : 670
# error index : 1097
# error menu : 생과일&요거트
# # of error : 671
# error index : 1099
# error menu : 자반고등어찜2
# # of error : 672
# error index : 1102
# error menu : 깍두기(손칼)
# # of error : 673
# error index : 1103
# error menu : 비빔밥(표고)
# # of error : 674
# error index : 1105
# error menu : 잡채(어묵)
# # of error : 675
# error index : 1106
# error menu : 닭조림(토막)
# # of error : 676
# error index : 1107
# error menu : 깍두기(손칼)
# # of error : 677
# error index : 1108
# error menu : 닭불고기(180)
# # of error : 678
# error index : 1109
# error menu : 깍두기(손칼)
# # of error : 679
# error index : 1114
# error menu : 깍두기(손칼)
# # of error : 680
# error index : 1114
# error menu : 잡채(어묵)
# # of error : 681
# error index : 1119
# error menu : 닭조림(토막)
# # of error : 682
# error index : 1120
# error menu : 옥수수고로케(천일)
# # of error : 683
# error index : 1120
# error menu : 자반고등어찜2
# # of error : 684
# error index : 1121
# error menu : 파인애플(I중)
# # of error : 685
# error index : 1124
# error menu : 야채튀김(쑥갓)
# # of error : 686
# error index : 1125
# error menu : 깍두기(손칼)
# # of error : 687
# error index : 1130
# error menu : 무생채(잔파)
# # of error : 688
# error index : 1133
# error menu : 깍두기(손칼)
# # of error : 689
# error index : 1135
# error menu : 삼치구이&데리야끼소스
# # of error : 690
# error index : 1135
# error menu : 잡채(어묵)
# # of error : 691
# error index : 1138
# error menu : 깍두기(손칼)
# # of error : 692
# error index : 1146
# error menu : 잡채(어묵)
# # of error : 693
# error index : 1149
# error menu : 깍두기(손칼)
# # of error : 694
# error index : 1150
# error menu : 연두부양념장(반모)
# # of error : 695
# error index : 1151
# error menu : 무생채(잔파)
# # of error : 696
# error index : 1156
# error menu : 삼치구이&데리야끼소스
# # of error : 697
# error index : 1156
# error menu : 잡채(어묵)
# # of error : 698
# error index : 1158
# error menu : 깍두기(손칼)
# # of error : 699
# error index : 1158
# error menu : 오렌지(반)
# # of error : 700
# error index : 1161
# error menu : 잡채(어묵)
# # of error : 701
# error index : 1162
# error menu : 닭조림(토막)
# # of error : 702
# error index : 1163
# error menu : 깍두기(손칼)
# # of error : 703
# error index : 1164
# error menu : 미숫가루2
# # of error : 704
# error index : 1166
# error menu : 미숫가루2
# # of error : 705
# error index : 1170
# error menu : 깍두기(손칼)
# # of error : 706
# error index : 1172
# error menu : 깍두기(손칼)
# # of error : 707
# error index : 1172
# error menu : 잡채(어묵)
# # of error : 708
# error index : 1176
# error menu : 삼치구이&데리야끼소스
# # of error : 709
# error index : 1176
# error menu : 온두부&볶음김치
# # of error : 710
# error index : 1180
# error menu : 깍두기(손칼)
# # of error : 711
# error index : 1181
# error menu : 깍두기(손칼)
# # of error : 712
# error index : 1188
# error menu : 후라이드치킨(토막)
# # of error : 713
# error index : 1191
# error menu : 닭조림(부분)
# # of error : 714
# error index : 1193
# error menu : 잡채(어묵)
# # of error : 715
# error index : 1196
# error menu : 깍두기(손칼)
# # of error : 716
# error index : 1197
# error menu : 깍두기(손칼)
# # of error : 717
# error index : 1198
# error menu : 무채국(콩가루)
# # of error : 718
# error index : 1203
# error menu : 생선까스&타르
# # of error : 719
# error index : 1205
# error menu : 깍두기(손칼)
# # of error : 720
# error index : 1207
# error menu : 무생채(잔파)
# # of error : 721
# error index : 1209
# error menu : 잡채(어묵)
# # of error : 722
# error index : 1210
# error menu : 돌나물&초고추장
# # of error : 723
# error index : 1211
# error menu : 닭파인애플조림(토막)
# # of error : 724
# error index : 1213
# error menu : 깍두기(손칼)
# # of error : 725
# error index : 1216
# error menu : 다시마채무침(무)
# # of error : 726
# error index : 1218
# error menu : 고구마순볶음(포)
# # of error : 727
# error index : 1219
# error menu : 잡채(어묵)
# # of error : 728
# error index : 1220
# error menu : 돌나물&초고추장
# # of error : 729
# error index : 1220
# error menu : 생선까스&타르
# # of error : 730
# error index : 1222
# error menu : 깍두기(손칼)
# # of error : 731
# error index : 1224
# error menu : 해장국(목뼈)
# # of error : 732
# error index : 1227
# error menu : 비빔밥(표고)
# # of error : 733
# error index : 1228
# error menu : 무생채(잔파)
# # of error : 734
# error index : 1229
# error menu : 깍두기(손칼)
# # of error : 735
# error index : 1233
# error menu : 돌나물&초고추장
# # of error : 736
# error index : 1233
# error menu : 잡채(어묵)
# # of error : 737
# error index : 1236
# error menu : 깍두기(손칼)
# # of error : 738
# error index : 1238
# error menu : 옥수수고로케(천일)
# # of error : 739
# error index : 1241
# error menu : 깍두기(손칼)
# # of error : 740
# error index : 1242
# error menu : 야채튀김(쑥갓)
# # of error : 741
# error index : 1243
# error menu : 다시마채무침(무)
# # of error : 742
# error index : 1244
# error menu : 온두부&볶음김치
# # of error : 743
# error index : 1245
# error menu : 깍두기(손칼)
# # of error : 744
# error index : 1248
# error menu : 삼겹살구이2
# # of error : 745
# error index : 1255
# error menu : 깍두기(손칼)
# # of error : 746
# error index : 1258
# error menu : 무생채(잔파)
# # of error : 747
# error index : 1261
# error menu : 깍두기(손칼)
# # of error : 748
# error index : 1266
# error menu : 미역줄기볶음(편)
# # of error : 749
# error index : 1267
# error menu : 우엉조림(엇우엉)
# # of error : 750
# error index : 1269
# error menu : 모듬튀김(만.당.오)
# # of error : 751
# error index : 1271
# error menu : 잡채(어묵)
# # of error : 752
# error index : 1272
# error menu : 카레라이스(브로콜리)
# # of error : 753
# error index : 1273
# error menu : 삼치구이&데리야끼소스
# # of error : 754
# error index : 1276
# error menu : 깍두기(손칼)
# # of error : 755
# error index : 1278
# error menu : 깍두기(손칼)
# # of error : 756
# error index : 1280
# error menu : 연두부양념장(반모)
# # of error : 757
# error index : 1283
# error menu : 깍두기(손칼)
# # of error : 758
# error index : 1283
# error menu : 미숫가루2
# # of error : 759
# error index : 1284
# error menu : 삼치구이&데리야끼소스
# # of error : 760
# error index : 1284
# error menu : 온두부&볶음김치
# # of error : 761
# error index : 1288
# error menu : 깍두기(손칼)
# # of error : 762
# error index : 1290
# error menu : 비빔밥(표고)
# # of error : 763
# error index : 1294
# error menu : 잡채(어묵)
# # of error : 764
# error index : 1295
# error menu : 깍두기(손칼)
# # of error : 765
# error index : 1297
# error menu : 깍두기(손칼)
# # of error : 766
# error index : 1297
# error menu : 순대국밥(뼈)
# # of error : 767
# error index : 1298
# error menu : 잡채(돈):사무직
# # of error : 768
# error index : 1299
# error menu : 미역줄기볶음(편)
# # of error : 769
# error index : 1302
# error menu : 잡채(어묵)
# # of error : 770
# error index : 1303
# error menu : 비빔밥(표고)
# # of error : 771
# error index : 1303
# error menu : 우무콩국(후식)
# # of error : 772
# error index : 1305
# error menu : 쌀밥(반공기)
# # of error : 773
# error index : 1307
# error menu : 깍두기(손칼)
# # of error : 774
# error index : 1307
# error menu : 옥수수고로케(천일)
# # of error : 775
# error index : 1309
# error menu : 깍두기(손칼)
# # of error : 776
# error index : 1309
# error menu : 미숫가루2
# # of error : 777
# error index : 1310
# error menu : 미역줄기볶음(편)
# # of error : 778
# error index : 1315
# error menu : 깍두기(손칼)
# # of error : 779
# error index : 1319
# error menu : 야채튀김(쑥갓)
# # of error : 780
# error index : 1323
# error menu : 삼치구이&데리야끼소스
# # of error : 781
# error index : 1326
# error menu : 깍두기(손칼)
# # of error : 782
# error index : 1326
# error menu : 다시마채무침(무)
# # of error : 783
# error index : 1326
# error menu : 온두부&볶음김치
# # of error : 784
# error index : 1332
# error menu : 잡채(어묵)
# # of error : 785
# error index : 1333
# error menu : 파절이(콩나물.양파.대파)
# # of error : 786
# error index : 1336
# error menu : 탕수어&황도소스
# # of error : 787
# error index : 1339
# error menu : 쌀밥(반공기)
# # of error : 788
# error index : 1343
# error menu : 깍두기(손칼)
# # of error : 789
# error index : 1343
# error menu : 생선까스&타르
# # of error : 790
# error index : 1345
# error menu : 비빔밥(표고)
# # of error : 791
# error index : 1346
# error menu : 깍두기(손칼)
# # of error : 792
# error index : 1350
# error menu : 미역줄기볶음(편)
# # of error : 793
# error index : 1351
# error menu : 순대국밥(뼈)
# # of error : 794
# error index : 1352
# error menu : 삼치구이&데리야끼소스
# # of error : 795
# error index : 1352
# error menu : 잡채(어묵)
# # of error : 796
# error index : 1353
# error menu : 파절이(콩나물.양파.대파)
# # of error : 797
# error index : 1354
# error menu : 무생채(잔파)
# # of error : 798
# error index : 1356
# error menu : 우엉콩조림(흑콩)
# # of error : 799
# error index : 1361
# error menu : 우엉조림(엇우엉)
# # of error : 800
# error index : 1364
# error menu : 깍두기(손칼)
# # of error : 801
# error index : 1367
# error menu : 깍두기(손칼)
# # of error : 802
# error index : 1374
# error menu : 비빔밥(표고)
# # of error : 803
# error index : 1377
# error menu : 옥수수고로케(천일)
# # of error : 804
# error index : 1380
# error menu : 깍두기(손칼)
# # of error : 805
# error index : 1382
# error menu : 깍두기(손칼)
# # of error : 806
# error index : 1386
# error menu : 무생채(잔파)
# # of error : 807
# error index : 1387
# error menu : 다시마채무침(무)
# # of error : 808
# error index : 1389
# error menu : 잡채(어묵)
# # of error : 809
# error index : 1391
# error menu : 깍두기(손칼)
# # of error : 810
# error index : 1394
# error menu : 비빔밥(표고)
# # of error : 811
# error index : 1395
# error menu : 무생채(잔파)
# # of error : 812
# error index : 1396
# error menu : 잡채(어묵)
# # of error : 813
# error index : 1398
# error menu : 깍두기(손칼)
# # of error : 814
# error index : 1399
# error menu : 무생채(잔파)
# # of error : 815
# error index : 1400
# error menu : 깍두기(손칼)
# # of error : 816
# error index : 1401
# error menu : 깍두기(손칼)
# # of error : 817
# error index : 1403
# error menu : 닭불고기(180)
# # of error : 818
# error index : 1404
# error menu : 깍두기(손칼)
# # of error : 819
# error index : 1409
# error menu : 잡채(어묵)
# # of error : 820
# error index : 1415
# error menu : 깍두기(손칼)
# # of error : 821
# error index : 1416
# error menu : 깍두기(손칼)
# # of error : 822
# error index : 1416
# error menu : 야채튀김(쑥갓)
# # of error : 823
# error index : 1421
# error menu : 깍두기(손칼)
# # of error : 824
# error index : 1422
# error menu : 무생채(잔파)
# # of error : 825
# error index : 1424
# error menu : 깍두기(손칼)
# # of error : 826
# error index : 1427
# error menu : 잡채(어묵)
# # of error : 827
# error index : 1432
# error menu : 비빔밥(표고)
# # of error : 828
# error index : 1435
# error menu : 무생채(잔파)
# # of error : 829
# error index : 1437
# error menu : 무생채(잔파)
# # of error : 830
# error index : 1439
# error menu : 깍두기(손칼)
# # of error : 831
# error index : 1440
# error menu : 미역줄기볶음(편)
# # of error : 832
# error index : 1447
# error menu : 잡채(어묵)
# # of error : 833
# error index : 1448
# error menu : 삼치구이&데리야끼소스
# # of error : 834
# error index : 1449
# error menu : 깍두기(손칼)
# # of error : 835
# error index : 1451
# error menu : 깍두기(손칼)
# # of error : 836
# error index : 1451
# error menu : 오렌지(반)
# # of error : 837
# error index : 1452
# error menu : 잡채(어묵)
# # of error : 838
# error index : 1453
# error menu : 야채튀김(쑥갓)
# # of error : 839
# error index : 1455
# error menu : 야채튀김(쑥갓)
# # of error : 840
# error index : 1456
# error menu : 깍두기(손칼)
# # of error : 841
# error index : 1458
# error menu : 깍두기(손칼)
# # of error : 842
# error index : 1458
# error menu : 온두부&볶음김치
# # of error : 843
# error index : 1459
# error menu : 잡채(어묵)
# # of error : 844
# error index : 1461
# error menu : 무생채(잔파)
# # of error : 845
# error index : 1463
# error menu : 야채튀김(쑥갓)
# # of error : 846
# error index : 1469
# error menu : 깍두기(손칼)
# ...
# # of error : 905
# error index : 1606
# error menu : 잡채(어묵)
# # of error : 906
# error index : 1610
# error menu : 자반고등어찜2
# # of error : 907
# error index : 1613
# error menu : 깍두기(손칼)
# # of error : 908
# error index : 1615
# error menu : 잡채(어묵)
# # of error : 909
# error index : 1616
# error menu : 비빔밥(표고)
# # of error : 910
# error index : 1618
# error menu : 깍두기(손칼)
# # of error : 911
# error index : 1621
# error menu : 깍두기(손칼)
# # of error : 912
# error index : 1624
# error menu : 깍두기(손칼)
# # of error : 913
# error index : 1628
# error menu : 방어강정(엿장)
# # of error : 914
# error index : 1630
# error menu : 자반고등어찜2
# # of error : 915
# error index : 1640
# error menu : 깍두기(손칼)
# # of error : 916
# error index : 1641
# error menu : 비빔밥(표고)
# # of error : 917
# error index : 1645
# error menu : 깍두기(손칼)
# # of error : 918
# error index : 1649
# error menu : 깍두기(손칼)
# # of error : 919
# error index : 1649
# error menu : 잡채(어묵)
# # of error : 920
# error index : 1652
# error menu : 깍두기(손칼)
# # of error : 921
# error index : 1654
# error menu : 깍두기(손칼)
# # of error : 922
# error index : 1654
# error menu : 순대국밥(뼈)
# # of error : 923
# error index : 1661
# error menu : 깍두기(손칼)
# # of error : 924
# error index : 1663
# error menu : 잡채(어묵)
# # of error : 925
# error index : 1664
# error menu : 방어강정(엿장)
# # of error : 926
# error index : 1666
# error menu : 다시마채무침(무)
# # of error : 927
# error index : 1667
# error menu : 깍두기(손칼)
# # of error : 928
# error index : 1669
# error menu : 무생채(잔파)
# # of error : 929
# error index : 1670
# error menu : 비빔밥(표고)
# # of error : 930
# error index : 1673
# error menu : 깍두기(손칼)
# # of error : 931
# error index : 1676
# error menu : 깍두기(손칼)
# # of error : 932
# error index : 1682
# error menu : 깍두기(손칼)
# # of error : 933
# error index : 1684
# error menu : 깍두기(손칼)
# # of error : 934
# error index : 1687
# error menu : 닭불고기(180)
# # of error : 935
# error index : 1690
# error menu : 비빔밥(표고)
# # of error : 936
# error index : 1691
# error menu : 깍두기(손칼)
# # of error : 937
# error index : 1692
# error menu : 깍두기(손칼)
# # of error : 938
# error index : 1693
# error menu : 방어강정(엿장)
# # of error : 939
# error index : 1693
# error menu : 쌀밥(반공기)
# # of error : 940
# error index : 1694
# error menu : 잡채(어묵)
# # of error : 941
# error index : 1697
# error menu : 잡채(어묵)
# # of error : 942
# error index : 1698
# error menu : 무생채(잔파)
# # of error : 943
# error index : 1703
# error menu : 잡채(어묵)
# # of error : 944
# error index : 1704
# error menu : 깍두기(손칼)
# # of error : 945
# error index : 1704
# error menu : 방어강정(엿장)
# # of error : 946
# error index : 1707
# error menu : 깍두기(손칼)
# # of error : 947
# error index : 1708
# error menu : 닭조림(토막)
# # of error : 948
# error index : 1714
# error menu : 깍두기(손칼)
# # of error : 949
# error index : 1717
# error menu : 깍두기(손칼)
# # of error : 950
# error index : 1719
# error menu : 깍두기(손칼)
# # of error : 951
# error index : 1724
# error menu : 깍두기(손칼)
# # of error : 952
# error index : 1728
# error menu : 잡채(어묵)
# # of error : 953
# error index : 1731
# error menu : 깍두기(손칼)
# # of error : 954
# error index : 1734
# error menu : 깍두기(손칼)
# # of error : 955
# error index : 1735
# error menu : 잡채(어묵)
# # of error : 956
# error index : 1737
# error menu : 다시마채무침(무)
# # of error : 957
# error index : 1738
# error menu : 깍두기(손칼)
# # of error : 958
# error index : 1739
# error menu : 깍두기(손칼)
# # of error : 959
# error index : 1739
# error menu : 오렌지(반)
# # of error : 960
# error index : 1741
# error menu : 깍두기(손칼)
# # of error : 961
# error index : 1741
# error menu : 온두부&볶음김치
# # of error : 962
# error index : 1745
# error menu : 깍두기(손칼)
# # of error : 963
# error index : 1747
# error menu : 비빔밥(표고)
# # of error : 964
# error index : 1749
# error menu : 잡채(어묵)
# # of error : 965
# error index : 1759
# error menu : 깍두기(손칼)
# # of error : 966
# error index : 1761
# error menu : 잡채(어묵)
# # of error : 967
# error index : 1763
# error menu : 깍두기(손칼)
# # of error : 968
# error index : 1763
# error menu : 온두부&볶음김치
# # of error : 969
# error index : 1766
# error menu : 잡채(어묵)
# # of error : 970
# error index : 1775
# error menu : 비빔밥(표고)
# # of error : 971
# error index : 1776
# error menu : 잡채(어묵)
# # of error : 972
# error index : 1778
# error menu : 미역줄기볶음(편)
# # of error : 973
# error index : 1783
# error menu : 잡채(어묵)
# # of error : 974
# error index : 1786
# error menu : 무생채(잔파)
# # of error : 975
# error index : 1788
# error menu : 깍두기(손칼)
# # of error : 976
# error index : 1788
# error menu : 잡채(어묵)
# # of error : 977
# error index : 1790
# error menu : 깍두기(손칼)
# # of error : 978
# error index : 1791
# error menu : 파래김&양념장
# # of error : 979
# error index : 1793
# error menu : 미숫가루2
# # of error : 980
# error index : 1793
# error menu : 잡채(어묵)
# # of error : 981
# error index : 1794
# error menu : 깍두기(손칼)
# # of error : 982
# error index : 1802
# error menu : 깍두기(손칼)
# # of error : 983
# error index : 1803
# error menu : 비빔밥(표고)
# # of error : 984
# error index : 1809
# error menu : 깍두기(손칼)
# # of error : 985
# error index : 1811
# error menu : 고구마순볶음(포)
# # of error : 986
# error index : 1811
# error menu : 방어강정(엿장)
# # of error : 987
# error index : 1812
# error menu : 무생채(잔파)
# # of error : 988
# error index : 1815
# error menu : 깍두기(손칼)
# # of error : 989
# error index : 1818
# error menu : 온두부&볶음김치
# # of error : 990
# error index : 1818
# error menu : 잡채(어묵)
# # of error : 991
# error index : 1822
# error menu : 깍두기(손칼)
# # of error : 992
# error index : 1828
# error menu : 잡채(어묵)
# # of error : 993
# error index : 1830
# error menu : 비빔밥(표고)
# # of error : 994
# error index : 1832
# error menu : 깍두기(손칼)
# # of error : 995
# error index : 1838
# error menu : 깍두기(손칼)
# # of error : 996
# error index : 1838
# error menu : 온두부&볶음김치
# # of error : 997
# error index : 1839
# error menu : 비빔밥(표고)
# # of error : 998
# error index : 1841
# error menu : 깍두기(손칼)
# # of error : 999
# error index : 1841
# error menu : 잡채(어묵)
# # of error : 1000
# error index : 1846
# error menu : 잡채(어묵)
# # of error : 1001
# error index : 1847
# error menu : 다시마채무침(무)
# # of error : 1002
# error index : 1849
# error menu : 깍두기(손칼)
# # of error : 1003
# error index : 1849
# error menu : 온두부&볶음김치
# # of error : 1004
# error index : 1850
# error menu : 잡채(어묵)
# # of error : 1005
# error index : 1851
# error menu : 카레라이스(브로콜리)
# # of error : 1006
# error index : 1852
# error menu : 깍두기(손칼)
# # of error : 1007
# error index : 1861
# error menu : 비빔밥(표고)
# # of error : 1008
# error index : 1866
# error menu : 깍두기(손칼)
# # of error : 1009
# error index : 1867
# error menu : 순대국밥(뼈)
# # of error : 1010
# error index : 1875
# error menu : 야채(간보호)
# # of error : 1011
# error index : 1876
# error menu : 깍두기(손칼)
# # of error : 1012
# error index : 1879
# error menu : 잡채(어묵)
# # of error : 1013
# error index : 1881
# error menu : 닭불고기(180)
# # of error : 1014
# error index : 1882
# error menu : 비빔밥(표고)
# # of error : 1015
# error index : 1884
# error menu : 잡채(어묵)
# # of error : 1016
# error index : 1885
# error menu : 쌀밥(반공기)
# # of error : 1017
# error index : 1886
# error menu : 무생채(잔파)
# # of error : 1018
# error index : 1890
# error menu : 카레라이스(브로콜리)
# # of error : 1019
# error index : 1890
# error menu : 후라이드치킨(토막)
# # of error : 1020
# error index : 1891
# error menu : 탕수어&황도소스
# # of error : 1021
# error index : 1892
# error menu : 깍두기(손칼)
# # of error : 1022
# error index : 1894
# error menu : 쌀밥(반공기)
# # of error : 1023
# error index : 1895
# error menu : 깍두기(손칼)
# # of error : 1024
# error index : 1896
# error menu : 깍두기(손칼)
# # of error : 1025
# error index : 1897
# error menu : 깍두기(손칼)
# # of error : 1026
# error index : 1899
# error menu : 비빔밥(표고)
# # of error : 1027
# error index : 1902
# error menu : 흑미밥(현장)
# # of error : 1028
# error index : 1904
# error menu : 흑미밥(현장)
# # of error : 1029
# error index : 1906
# error menu : 삼치구이&데리야끼소스
# # of error : 1030
# error index : 1906
# error menu : 흑미밥(현장)
# # of error : 1031
# error index : 1909
# error menu : 깍두기(손칼)
# # of error : 1032
# error index : 1909
# error menu : 흑미밥(현장)
# # of error : 1033
# error index : 1910
# error menu : 온두부&볶음김치
# # of error : 1034
# error index : 1911
# error menu : 흑미밥(현장)
# # of error : 1035
# error index : 1912
# error menu : 깍두기(손칼)
# # of error : 1036
# error index : 1913
# error menu : 깍두기(손칼)
# # of error : 1037
# error index : 1913
# error menu : 온두부&볶음김치
# # of error : 1038
# error index : 1915
# error menu : 삼치구이&데리야끼소스
# # of error : 1039
# error index : 1917
# error menu : 깍두기(손칼)
# # of error : 1040
# error index : 1924
# error menu : 깍두기(손칼)
# # of error : 1041
# error index : 1926
# error menu : 잡채(생선묵):연
# # of error : 1042
# error index : 1929
# error menu : 깍두기(손칼)
# # of error : 1043
# error index : 1930
# error menu : 깍두기(손칼)
# # of error : 1044
# error index : 1930
# error menu : 양념통닭(토막)
# # of error : 1045
# error index : 1932
# error menu : 모듬볼튀김(오미새)
# # of error : 1046
# error index : 1933
# error menu : 깍두기(손칼)
# # of error : 1047
# error index : 1933
# error menu : 옥수수샐러드(올)
# # of error : 1048
# error index : 1938
# error menu : 온두부&볶음김치
# # of error : 1049
# error index : 1942
# error menu : 깍두기(손칼)
# # of error : 1050
# error index : 1942
# error menu : 생선까스&타르
# # of error : 1051
# error index : 1943
# error menu : 잡채(돈):사무직
# # of error : 1052
# error index : 1944
# error menu : 쌀밥(반공기)
# # of error : 1053
# error index : 1945
# error menu : 깍두기(손칼)
# # of error : 1054
# error index : 1947
# error menu : 모듬튀김(만.당.오)
# # of error : 1055
# error index : 1948
# error menu : 흑미밥(현장)
# # of error : 1056
# error index : 1949
# error menu : 비빔밥(표고)
# # of error : 1057
# error index : 1951
# error menu : 온두부&볶음김치
# # of error : 1058
# error index : 1953
# error menu : 깍두기(손칼)
# # of error : 1059
# error index : 1955
# error menu : 비빔밥(표고)
# # of error : 1060
# error index : 1956
# error menu : 깍두기(손칼)
# # of error : 1061
# error index : 1957
# error menu : 군만두(양념장)
# # of error : 1062
# error index : 1961
# error menu : 흑미밥(현장)
# # of error : 1063
# error index : 1962
# error menu : 쌀밥(반공기)
# # of error : 1064
# error index : 1963
# error menu : 흑미밥(현장)
# # of error : 1065
# error index : 1964
# error menu : 깍두기(손칼)
# # of error : 1066
# error index : 1965
# error menu : 흑미밥(현장)
# # of error : 1067
# error index : 1966
# error menu : 깍두기(손칼)
# # of error : 1068
# error index : 1968
# error menu : 흑미밥(현장)
# # of error : 1069
# error index : 1971
# error menu : 다시마채무침(무)
# # of error : 1070
# error index : 1975
# error menu : 쇠고기콩나물국(된장)
# # of error : 1071
# error index : 1975
# error menu : 온두부&볶음김치
# # of error : 1072
# error index : 1976
# error menu : 깍두기(손칼)
# # of error : 1073
# error index : 1976
# error menu : 쌀밥(반공기)
# # of error : 1074
# error index : 1977
# error menu : 깍두기(손칼)
# # of error : 1075
# error index : 1977
# error menu : 우무콩국(후식)
# # of error : 1076
# error index : 1978
# error menu : 흑미밥(현장)
# # of error : 1077
# error index : 1979
# error menu : 깍두기(손칼)
# # of error : 1078
# error index : 1979
# error menu : 쌀밥(반공기)
# # of error : 1079
# error index : 1979
# error menu : 한방닭백숙(반마리)
# # of error : 1080
# error index : 1981
# error menu : 깍두기(손칼)
# # of error : 1081
# error index : 1985
# error menu : 양념통닭(토막)
# # of error : 1082
# error index : 1985
# error menu : 카레라이스(브로콜리)
# # of error : 1083
# error index : 1987
# error menu : 비빔밥(표고)
# # of error : 1084
# error index : 1988
# error menu : 깍두기(손칼)
# # of error : 1085
# error index : 1988
# error menu : 탕수육(후르츠)
# # of error : 1086
# error index : 1990
# error menu : 쌀밥(반공기)
# # of error : 1087
# error index : 1991
# error menu : 무생채(미나리)
# # of error : 1088
# error index : 1993
# error menu : 깍두기(손칼)
# # of error : 1089
# error index : 1994
# error menu : 깍두기(손칼)
# # of error : 1090
# error index : 1999
# error menu : 깍두기(손칼)
# # of error : 1091
# error index : 2005
# error menu : 깍두기(손칼)
# # of error : 1092
# error index : 2005
# error menu : 온두부&볶음김치
# # of error : 1093
# error index : 2010
# error menu : 깍두기(손칼)
# # of error : 1094
# error index : 2011
# error menu : 쑥갓양파겉절이2
# # of error : 1095
# error index : 2015
# error menu : 군만두(양념장)
# # of error : 1096
# error index : 2016
# error menu : 옥수수샐러드(올)
# # of error : 1097
# error index : 2017
# error menu : 무오이초(수)
# # of error : 1098
# error index : 2019
# error menu : 깍두기(손칼)
# # of error : 1099
# error index : 2020
# error menu : 닭불고기(180)
# # of error : 1100
# error index : 2020
# error menu : 파절이(콩나물.양파.대파)
# # of error : 1101
# error index : 2022
# error menu : 깍두기(손칼)
# # of error : 1102
# error index : 2023
# error menu : 쌈장2
# # of error : 1103
# error index : 2025
# error menu : 깍두기(손칼)
# # of error : 1104
# error index : 2027
# error menu : 잡채(돈육)
# # of error : 1105
# error index : 2029
# error menu : 비빔밥(표고)
# # of error : 1106
# error index : 2030
# error menu : 김말이&춘권튀김
# # of error : 1107
# error index : 2032
# error menu : 파절이(콩나물.양파.대파)
# # of error : 1108
# error index : 2033
# error menu : 쌀밥(반공기)
# # of error : 1109
# error index : 2035
# error menu : 깍두기(손칼)
# # of error : 1110
# error index : 2036
# error menu : 깍두기(손칼)
# # of error : 1111
# error index : 2039
# error menu : 깍두기(손칼)
# # of error : 1112
# error index : 2039
# error menu : 닭불고기(180)
# # of error : 1113
# error index : 2039
# error menu : 생선까스&타르
# # of error : 1114
# error index : 2040
# error menu : 깍두기(손칼)
# # of error : 1115
# error index : 2044
# error menu : 쌈배추(숙쌈)
# # of error : 1116
# error index : 2051
# error menu : 카레라이스(브로콜리)
# # of error : 1117
# error index : 2052
# error menu : 마늘쫑&쌈장
# # of error : 1118
# error index : 2052
# error menu : 무생채(잔파)
# # of error : 1119
# error index : 2052
# error menu : 순대국밥(뼈)
# # of error : 1120
# error index : 2056
# error menu : 닭불고기(180)
# # of error : 1121
# error index : 2058
# error menu : 깍두기(손칼)
# # of error : 1122
# error index : 2058
# error menu : 양념통닭(토막)
# # of error : 1123
# error index : 2060
# error menu : 깍두기(손칼)
# # of error : 1124
# error index : 2061
# error menu : 순대&쌈장
# # of error : 1125
# error index : 2063
# error menu : 깍두기(손칼)
# # of error : 1126
# error index : 2063
# error menu : 온두부&볶음김치
# # of error : 1127
# error index : 2069
# error menu : 모듬커틀렛(새
# # of error : 1128
# error index : 2069
# error menu : 휘)
# # of error : 1129
# error index : 2071
# error menu : 깍두기(손칼)
# # of error : 1130
# error index : 2072
# error menu : 생선까스&타르
# # of error : 1131
# error index : 2073
# error menu : 닭불고기(180)
# # of error : 1132
# error index : 2074
# error menu : 무생채(미나리)
# # of error : 1133
# error index : 2078
# error menu : 닭불고기(180)
# # of error : 1134
# error index : 2079
# error menu : 깍두기(손칼)
# # of error : 1135
# error index : 2081
# error menu : 소방어무조림(가공)
# # of error : 1136
# error index : 2082
# error menu : 깍두기(손칼)
# # of error : 1137
# error index : 2090
# error menu : 깍두기(손칼)
# # of error : 1138
# error index : 2100
# error menu : 무생채(잔파)
# # of error : 1139
# error index : 2101
# error menu : 깍두기(손칼)
# # of error : 1140
# error index : 2106
# error menu : 깍두기(손칼)
# # of error : 1141
# error index : 2108
# error menu : 깍두기(손칼)
# # of error : 1142
# error index : 2112
# error menu : 깍두기(손칼)
# # of error : 1143
# error index : 2112
# error menu : 온두부&볶음김치
# # of error : 1144
# error index : 2113
# error menu : 깍두기(손칼)
# # of error : 1145
# error index : 2117
# error menu : 깍두기(손칼)
# # of error : 1146
# error index : 2118
# error menu : 야채튀김(쑥갓)
# # of error : 1147
# error index : 2119
# error menu : 잡채(어묵)
# # of error : 1148
# error index : 2121
# error menu : 모듬커틀렛(새
# # of error : 1149
# error index : 2121
# error menu : 휘)
# # of error : 1150
# error index : 2121
# error menu : 카레라이스(브로콜리)
# # of error : 1151
# error index : 2126
# error menu : 깍두기(손칼)
# # of error : 1152
# error index : 2131
# error menu : 순대국밥(뼈)
# # of error : 1153
# error index : 2138
# error menu : 깍두기(손칼)
# # of error : 1154
# error index : 2141
# error menu : 김말이&춘권튀김
# # of error : 1155
# error index : 2142
# error menu : 무생채(잔파)
# # of error : 1156
# error index : 2144
# error menu : 미나리전(초고추장)
# # of error : 1157
# error index : 2145
# error menu : 생선까스&타르
# # of error : 1158
# error index : 2146
# error menu : 깍두기(손칼)
# # of error : 1159
# error index : 2147
# error menu : 비빔밥(표고)
# # of error : 1160
# error index : 2149
# error menu : 다시마채무침(무)
# # of error : 1161
# error index : 2152
# error menu : 깍두기(손칼)
# # of error : 1162
# error index : 2157
# error menu : 깍두기(손칼)
# # of error : 1163
# error index : 2159
# error menu : 깍두기(손칼)
# # of error : 1164
# error index : 2161
# error menu : 파절이(콩나물.양파.대파)
# # of error : 1165
# error index : 2163
# error menu : 닭불고기(180)
# # of error : 1166
# error index : 2164
# error menu : 무생채(미나리)
# # of error : 1167
# error index : 2166
# error menu : 깍두기(손칼)
# # of error : 1168
# error index : 2166
# error menu : 잡채(어묵)
# # of error : 1169
# error index : 2172
# error menu : 깍두기(손칼)
# # of error : 1170
# error index : 2173
# error menu : 깍두기(손칼)
# # of error : 1171
# error index : 2175
# error menu : 감자채베이컨볶음(I
# # of error : 1172
# error index : 2175
# error menu : 파절이(콩나물.양파.대파)
# # of error : 1173
# error index : 2180
# error menu : 깍두기(손칼)
# # of error : 1174
# error index : 2180
# error menu : 온두부&볶음김치
# # of error : 1175
# error index : 2186
# error menu : 깍두기(손칼)
# # of error : 1176
# error index : 2190
# error menu : 깍두기(손칼)
# # of error : 1177
# error index : 2194
# error menu : 카레라이스(브로콜리)
# # of error : 1178
# error index : 2198
# error menu : 깍두기(손칼)
# # of error : 1179
# error index : 2199
# error menu : 깍두기(손칼)
# # of error : 1180

# %%
menuKor.head(10)
# Out:
#            true_kor pred_kor  \
# date
# 2003-04-03  54.4404  51.2394
# 2003-04-04  43.1769  47.6012
# 2003-04-05  26.2816  29.7679
# 2003-04-06  28.1588  27.9009
# 2003-04-07  52.2022  50.5209
# 2003-04-08  49.0975  51.9613
# 2003-04-09  51.2635  49.0836
# 2003-04-10  49.9639  49.7338
# 2003-04-11  49.9639  50.1045
# 2003-04-12  37.4007  29.8822
#
#                                                     menuSplit  \
# date
# 2003-04-03        [물미역오이무침, 쌀밥, 아욱국, 쭈꾸미볶음, 참치김치볶음, 통두부, 양념장]
# 2003-04-04           [꽁치양념구이, 도라지풋마늘무침, 부추전, 쌀밥, 어묵무국, 잔멸치볶음]
# 2003-04-05                                   [비빔밥, 사과, 팽이버섯국]
# 2003-04-06        [돌나물겉절이, 쇠고기맑은국, 쌀밥, 양상치샐러드, 오징어회무침, 카레라이스]
# 2003-04-07       [꽈리고추찜, 닭불고기(180), 쌀밥, 오이양파무침, 콩나물국, 표고피망볶음]
# 2003-04-08         [계란찜, 동태매운탕(가공), 쇠고기야채볶음, 쌀밥, 우엉채조림, 잔파생채]
# 2003-04-09  [곰탕, 깍두기(손칼), 대추차, 쌀밥, 알감자조림, 오이, 풋고추, 쌈장, 오징어...
# 2003-04-10          [감자채볶음, 달래된장찌개, 메추리알조림, 생선까스, 쌀밥, 참나물겉절이]
# 2003-04-11         [건새우호박국, 불고기낙지찌개, 소면사리, 쌀밥, 잔파맛살무침, 콩나물무침]
# 2003-04-12                           [도라지풋마늘무침, 떡만두국, 오징어볼탕수]
#
#                                      menuMeterial
# date
# 2003-04-03          [채소, 곡류, 육류, 해산물, 김치, 채소, 소스]
# 2003-04-04            [해산물, 채소, 채소, 곡류, 해산물, 해산물]
# 2003-04-05                           [곡류, 과일, 채소]
# 2003-04-06              [채소, 육류, 곡류, 채소, 해산물, 곡류]
# 2003-04-07               [채소, 오류, 곡류, 채소, 채소, 채소]
# 2003-04-08            [육류(닭), 오류, 채소, 곡류, 채소, 채소]
# 2003-04-09  [육류, 오류, 음료, 곡류, 채소, 채소, 채소, 소스, 해산물]
# 2003-04-10           [채소, 채소, 육류(닭), 해산물, 곡류, 채소]
# 2003-04-11              [해산물, 해산물, 면, 곡류, 채소, 채소]
# 2003-04-12                           [채소, 육류, 튀김]
