# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import os
import shutil
from mpl_toolkits.mplot3d import Axes3D
from six.moves import cPickle

import pandas as pd

from sklearn.preprocessing import OneHotEncoder

from RNN import RNNmodel

# %% [markdown]
# # intervalDay 3일 버전

# %%
from six.moves import cPickle
intervalDay = 3
df_X7 = cPickle.load(open('./trainData{}.pkl'.format(intervalDay), 'rb'))
# df_Y7 = cPickle.load(open('./validDate{}.pkl'.format(intervalDay), 'rb'))
df_pred7 = cPickle.load(open('./predDate{}.pkl'.format(intervalDay), 'rb'))

# %%
df_X7['values_sum'] = df_X7['values_kor']+df_X7['values_west']
# df_Y7['values_sum'] = df_Y7['values_kor']+df_Y7['values_west']
df_pred7['values_sum'] = df_pred7['values_kor']+df_pred7['values_west']

# %%
trainWindow = []
# Train은 우선 바로앞만 예측하는걸로 학습
for orderIndex in df_X7.orderDf.unique():
    tempArray = df_X7[df_X7.orderDf == orderIndex][['date','values_kor','values_west','weekday','holiday']].values
    for i in range(len(tempArray)-(intervalDay+4)):
        trainWindow.append(tempArray[i:i+intervalDay+4])
        

# validWindow = []
# for orderIndex in df_Y7.orderDf.unique():
#     tempArray = df_Y7[df_Y7.orderDf == orderIndex][['date','values_kor','values_west','weekday','holiday']].values
#     validWindow.append(tempArray)        

    
predWindow = []
for orderIndex in df_pred7.orderDf.unique():
    tempArray = df_pred7[df_pred7.orderDf == orderIndex][['date','values_kor','values_west','weekday','holiday']].values
    predWindow.append(tempArray)  
    
trainArray = np.array(trainWindow)
# validArray = np.array(validWindow)
predArray = np.array(predWindow)

# %%
for i in predArray:
    print (i.shape, i[-1][0])
# Out:
# (9, 5) 2003-06-15 00:00:00
# (9, 5) 2004-03-01 00:00:00
# (9, 5) 2007-04-10 00:00:00
# (9, 5) 2007-12-11 00:00:00
# (9, 5) 2008-12-30 00:00:00
# (9, 5) 2009-01-23 00:00:00
# (9, 5) 2009-07-17 00:00:00
# (9, 5) 2010-07-15 00:00:00
# (9, 5) 2011-03-11 00:00:00
# (9, 5) 2011-05-05 00:00:00
# (9, 5) 2011-06-22 00:00:00
# (9, 5) 2011-07-18 00:00:00
# (9, 5) 2011-08-14 00:00:00
# (9, 5) 2011-09-14 00:00:00
# (9, 5) 2011-10-20 00:00:00
# (9, 5) 2012-01-03 00:00:00
# (9, 5) 2012-03-14 00:00:00
# (9, 5) 2012-05-13 00:00:00
# (9, 5) 2012-06-08 00:00:00
# (9, 5) 2012-07-02 00:00:00
# (9, 5) 2012-07-27 00:00:00
# (9, 5) 2012-10-02 00:00:00
# (9, 5) 2012-11-30 00:00:00
# (9, 5) 2013-01-09 00:00:00
# (9, 5) 2013-02-28 00:00:00
# (9, 5) 2013-03-24 00:00:00
# (9, 5) 2013-04-04 00:00:00
# (9, 5) 2013-07-31 00:00:00
# (9, 5) 2013-08-13 00:00:00
# (9, 5) 2013-09-16 00:00:00
# (9, 5) 2014-03-19 00:00:00
# (9, 5) 2014-05-29 00:00:00
# (9, 5) 2014-07-01 00:00:00
# (9, 5) 2014-08-22 00:00:00
# (9, 5) 2014-10-10 00:00:00
# (9, 5) 2014-12-12 00:00:00
# (9, 5) 2015-01-20 00:00:00
# (9, 5) 2015-03-23 00:00:00
# (9, 5) 2015-04-21 00:00:00
# (9, 5) 2015-06-07 00:00:00
# (9, 5) 2015-08-02 00:00:00
# (9, 5) 2015-09-18 00:00:00
# (9, 5) 2015-11-25 00:00:00
# (9, 5) 2015-12-25 00:00:00
# (9, 5) 2016-02-02 00:00:00
# (9, 5) 2016-04-05 00:00:00
# (9, 5) 2016-06-15 00:00:00
# (9, 5) 2016-07-20 00:00:00
# (9, 5) 2016-09-01 00:00:00
# (9, 5) 2016-10-19 00:00:00
# (9, 5) 2017-02-03 00:00:00
# (9, 5) 2017-03-26 00:00:00
# (9, 5) 2017-04-21 00:00:00
# (9, 5) 2017-07-18 00:00:00
# (9, 5) 2017-08-26 00:00:00
# (9, 5) 2017-10-10 00:00:00
# (9, 5) 2017-11-22 00:00:00
# (9, 5) 2014-06-06 00:00:00

# %%
realpredArray = []
for i in range(len(predArray)):
    if predArray[i].shape[0] > 9:
        predArray[i] = predArray[i][-9:]
    if predArray[i].shape[0] ==9:
        realpredArray.append(predArray[i])

# %%
realpredArray = np.array(realpredArray)

# %% [markdown]
# # 예측결과를 어떻게 분석하는가?
#
# - 일단 plot 하는걸 3일 맞추는거 말고도 특정 기간예측결과본 가지고와서 (for문 돌려서 3번째 날짜 쭉 맞추게해서) 경향을 맞추는지 살펴본다.
# - total, 서양, 한식 이 세가지 에 대해서 바로위에서 한게 잘 맞는지 살펴본다,
#
# - 위 두가지 하고난 후에야 학습때 사용되지않은 3일을 맞춰본다.
# - input 형태를 어떻게 할지 고민한다. (현재방식 뭔가 찝집함)
#
# - 별개로 메뉴를 활용할 방안을 살펴본다. (메뉴를 보는건 더이상 time 축을 고려하지 않아도 된다고 할 수 있다)

# %%
#enc = OneHotEncoder(n_values=7)
#trainArrayOhe = enc.fit_transform(trainArray[:, :, 1]).toarray().reshape(-1, 31, 7)*trainArray[:, :, [0]]
#validArrayOhe = enc.fit_transform(validArray[:, :, 2]).toarray().reshape(-1, 33, 7)

rnn_config = {
    'ID': 'posco_model',
    'rnn_ID' : 'RNNmodel0801_{}day'.format(intervalDay),
#     'rnn_ID' : 'load',
    'n_batch' : 100,
    'n_save' : 1000,
    'n_prt' : 50,
    'n_iter' : 500000,
    'LR' : 0.0001,
    'n_history' : 100,
    'n_input' : 3+7,
    'n_step' : intervalDay,
    'n_output' : 2, # values_sum은 pred 합으로 예측
    'intervalDay':intervalDay
}


try: 
    os.mkdir('./{}'.format(rnn_config['ID']))
except FileExistsError:
    pass

my_model = RNNmodel(rnn_config)
# Out:
# [FileExistsError] Will you remove directory? [Y/N] Y
# Model ID : posco_model
# Model saved at : ./posco_model/RNNmodel0801_3day

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(n_values=7)
trainArrayOhe = enc.fit_transform(trainArray[:, :, 3]).toarray().reshape(-1, intervalDay+4, 7)
# validArrayOhe = enc.fit_transform(validArray[:, :, 3]).toarray().reshape(-1, intervalDay+4, 7)
realpredArrayohe = enc.fit_transform(realpredArray[:, :, 3]).toarray().reshape(-1, intervalDay+3+3, 7)

# %%
def week_ohe(all_array, week_array):
    return np.concatenate((all_array[:, :, [0, 1, 2, 4]], week_array), 2)

# %%
train_idx = list(np.arange(0, 700))+list(np.arange(850,1500))+list(np.arange(1600,2800))+list(np.arange(2900,3236))
valid_idx = list(np.arange(750, 850))+list(np.arange(1500,1600))+list(np.arange(2800,2900))

trainX = week_ohe(trainArray, trainArrayOhe)[train_idx, :, 1:]
trainY = week_ohe(trainArray, trainArrayOhe)[train_idx, intervalDay+1:, 1:3]


validX = week_ohe(trainArray, trainArrayOhe)[valid_idx, :, 1:]
validY = week_ohe(trainArray, trainArrayOhe)[valid_idx, intervalDay+1:, 1:3]

# %%
my_model.fit(trainX, trainY, validX, validY)
# Out:
# 49/500001Your Train loss (50/500000) : 290.43133544921875
# Your Valid loss (50/500000) : 284.54864501953125
# 99/500001Your Train loss (100/500000) : 124.50041961669922
# Your Valid loss (100/500000) : 104.75774383544922
# 149/500001Your Train loss (150/500000) : 101.11202239990234
# Your Valid loss (150/500000) : 116.32365417480469
# 199/500001Your Train loss (200/500000) : 131.8287353515625
# Your Valid loss (200/500000) : 102.84825897216797
# 249/500001Your Train loss (250/500000) : 119.94189453125
# Your Valid loss (250/500000) : 102.92809295654297
# 299/500001Your Train loss (300/500000) : 109.39269256591797
# Your Valid loss (300/500000) : 98.22991180419922
# 349/500001Your Train loss (350/500000) : 107.7110366821289
# Your Valid loss (350/500000) : 89.13874053955078
# 399/500001Your Train loss (400/500000) : 80.83773803710938
# Your Valid loss (400/500000) : 67.0973129272461
# 449/500001Your Train loss (450/500000) : 79.58067321777344
# Your Valid loss (450/500000) : 70.2579116821289
# 499/500001Your Train loss (500/500000) : 48.39057159423828
# Your Valid loss (500/500000) : 46.25910949707031
# 549/500001Your Train loss (550/500000) : 41.244171142578125
# Your Valid loss (550/500000) : 58.69329071044922
# 599/500001Your Train loss (600/500000) : 33.527034759521484
# Your Valid loss (600/500000) : 41.472930908203125
# 649/500001Your Train loss (650/500000) : 37.458168029785156
# Your Valid loss (650/500000) : 49.94428634643555
# 699/500001Your Train loss (700/500000) : 43.229373931884766
# Your Valid loss (700/500000) : 42.752628326416016
# 749/500001Your Train loss (750/500000) : 29.827104568481445
# Your Valid loss (750/500000) : 47.304420471191406
# 799/500001Your Train loss (800/500000) : 44.12406921386719
# Your Valid loss (800/500000) : 50.15281295776367
# 849/500001Your Train loss (850/500000) : 30.765241622924805
# Your Valid loss (850/500000) : 42.6352653503418
# 899/500001Your Train loss (900/500000) : 35.52863693237305
# Your Valid loss (900/500000) : 37.23078155517578
# 949/500001Your Train loss (950/500000) : 25.907541275024414
# Your Valid loss (950/500000) : 46.66587448120117
# 999/500001Your Train loss (1000/500000) : 27.2642879486084
# Your Valid loss (1000/500000) : 48.32406234741211
# INFO:tensorflow:./posco_model/RNNmodel0801_3day/checkpoint/RNNmodel0801_3day_1000 is not in all_model_checkpoint_paths. Manually adding it.
# Your Valid loss (9000/500000) : 42.3364143371582
# INFO:tensorflow:./posco_model/RNNmodel0801_3day/checkpoint/RNNmodel0801_3day_9000 is not in all_model_checkpoint_paths. Manually adding it.
# 9049/500001Your Train loss (9050/500000) : 30.078777313232422
# Your Valid loss (9050/500000) : 49.33541488647461
# 9099/500001Your Train loss (9100/500000) : 30.46419906616211
# Your Valid loss (9100/500000) : 36.23003005981445
# 9149/500001Your Train loss (9150/500000) : 21.047657012939453
# Your Valid loss (9150/500000) : 39.254276275634766
# 9199/500001Your Train loss (9200/500000) : 30.969341278076172
# Your Valid loss (9200/500000) : 39.03516387939453
# 9249/500001Your Train loss (9250/500000) : 25.526527404785156
# Your Valid loss (9250/500000) : 53.43467330932617
# 9299/500001Your Train loss (9300/500000) : 32.98915100097656
# Your Valid loss (9300/500000) : 39.086692810058594
# 9349/500001Your Train loss (9350/500000) : 25.380870819091797
# Your Valid loss (9350/500000) : 44.90645980834961
# 9379/500001
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-15-7a9c3d6def84> in <module>()
# ----> 1 my_model.fit(trainX, trainY, validX, validY)
#
# /notebooks/sh_docker/Dropbox/KSH/project/posco/code/sh/challenge/peopleRNN/RNN.py in fit(self, TrainData, TrainLabel, ValidData, ValidLabel)
#     163             train_x_pred = train_x.copy()
#     164             for i in range(3):
# --> 165                 self.sess.run(self.optm, feed_dict={self.x : train_x_pred[:, i:i+self.intervalDay, :], self.y : train_y[:, i, :], self.seq_len : train_seq_len})
#     166                 if i!= 2:
#     167                     train_x_pred[:, i+1+self.intervalDay, 1:self.n_output+1] = self.predict(train_x_pred[:, i:i+self.intervalDay, :])
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1359   def _do_call(self, fn, *args):
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#    1363       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1338         else:
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#    1342     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(my_model.train_history)), my_model.train_history, 'b', label='trainloss')
plt.plot(np.arange(len(my_model.valid_history)), my_model.valid_history, 'r', label='validloss')
plt.legend()
plt.show()

# %%
my_model.load('./posco_model/RNNmodel0801_3day/checkpoint/RNNmodel0801_3day_9000')
# Out:
# INFO:tensorflow:Restoring parameters from ./posco_model/RNNmodel0801_3day/checkpoint/RNNmodel0801_3day_9000
# Model loaded from file : ./posco_model/RNNmodel0801_3day/checkpoint/RNNmodel0801_3day_9000

# %%
def predict_three(_array, my_model, intervalDay):
    enc = OneHotEncoder(n_values=7)
    _arrayohe = enc.fit_transform(_array[:, :, 3]).toarray().reshape(-1, _array.shape[1], 7)
    array = week_ohe(_array, _arrayohe)
    firstInput = array[:, :intervalDay, 1:].copy()

    firstResult = my_model.predict(firstInput)

    secondInput = array[:, 1:intervalDay+1, 1:].copy()
    secondInput[:, -1, 1:3] = firstResult
    secondResult = my_model.predict(secondInput)

    thirdInput = array[:, 2:intervalDay+2, 1:].copy()
    thirdInput[:, -1, 1:3] = secondResult
    thirdResult = my_model.predict(thirdInput)
    return np.concatenate((firstResult[:, np.newaxis, :], 
                           secondResult[:, np.newaxis, :], 
                           thirdResult[:, np.newaxis, :]), 1)

# %% [markdown]
# # 전체 날짜에대해서 (학습때쓴거) 비교하기

# %% [markdown]
# - RNN결과저장하기
# - 이제이걸로 예측할거

# %% [markdown]
# ## Train  index

# %%
predict_result = predict_three(trainArray[train_idx], my_model, intervalDay)

day = trainArray[train_idx, -1, 0]
week = trainArray[train_idx, -1, 3]
true_kor = trainArray[train_idx, -1, 1]
true_west = trainArray[train_idx, -1, 2]
pred_kor = predict_result[:, 2, 0]
pred_west = predict_result[:, 2, 1]



pred_train = np.concatenate((day[:, np.newaxis],
                             true_kor[:, np.newaxis], true_west[:, np.newaxis],
                             pred_kor[:, np.newaxis], pred_west[:, np.newaxis],
                            week[:, np.newaxis]),
                            1)

pred_train_df = pd.DataFrame(pred_train)
pred_train_df.columns = ['date', 'true_kor', 'true_west', 
                         'pred_kor', 'pred_west', 'week']

pred_train_df['true_sum'] = pred_train_df['true_kor']+pred_train_df['true_west']
pred_train_df['pred_sum'] = pred_train_df['pred_kor']+pred_train_df['pred_west']

# %%
pred_train_df
# Out:
#                      date true_kor true_west pred_kor  pred_west week  \
# 0     2003-03-08 00:00:00  42.7437         0  29.3452  -0.531624    5
# 1     2003-03-09 00:00:00  36.7509         0  23.9639   0.713213    6
# 2     2003-03-10 00:00:00   53.935         0  52.7339   0.613525    0
# 3     2003-03-11 00:00:00  56.5343         0  58.2544  -0.980935    1
# 4     2003-03-12 00:00:00  56.0289         0  55.0486  -0.853344    2
# 5     2003-03-13 00:00:00  56.6787         0  52.4077  -0.232617    3
# 6     2003-03-14 00:00:00  56.3177         0  50.7614    -0.3247    4
# 7     2003-03-15 00:00:00  40.2888         0  30.7047 -0.0882694    5
# 8     2003-03-16 00:00:00  33.7184         0  25.0706   0.849296    6
# 9     2003-03-17 00:00:00  57.6895         0  57.8711   0.115345    0
# 10    2003-03-18 00:00:00  61.7329         0  58.2505   -0.98413    1
# 11    2003-03-19 00:00:00  63.1047         0  54.9447  -0.650036    2
# 12    2003-03-20 00:00:00  59.5668         0  53.9171  0.0352264    3
# 13    2003-03-21 00:00:00  51.6245         0  53.6268 -0.0250225    4
# 14    2003-03-22 00:00:00   40.361         0  33.2711  -0.124309    5
# 15    2003-03-23 00:00:00  34.3682         0  27.2991   0.506607    6
# 16    2003-03-24 00:00:00  59.4946         0  57.8868  0.0162128    0
# 17    2003-03-25 00:00:00  56.8231         0  57.7675   -1.01579    1
# 18    2003-03-26 00:00:00  54.0072         0  55.7133  -0.528489    2
# 19    2003-03-27 00:00:00  43.6101         0  52.8422  -0.259077    3
# 20    2003-03-28 00:00:00  56.3899         0  51.3406  -0.414158    4
# 1     36.7509  24.6771
# 2      53.935  53.3474
# 3     56.5343  57.2734
# 4     56.0289  54.1952
# 5     56.6787  52.1751
# 6     56.3177  50.4367
# 7     40.2888  30.6164
# 8     33.7184  25.9199
# 9     57.6895  57.9865
# 10    61.7329  57.2663
# 11    63.1047  54.2946
# 12    59.5668  53.9523
# 13    51.6245  53.6018
# 14     40.361  33.1467
# 15    34.3682  27.8057
# 16    59.4946   57.903
# 17    56.8231  56.7517
# 18    54.0072  55.1848
# 19    43.6101  52.5831
# 20    56.3899  50.9265
# 21    40.5054  28.7554
# 22    28.1588  25.0906
# 23    54.2238  55.3059
# 24     46.426  56.5938
# 25    51.9856  51.6406
# 26    54.4404  47.2637
# 27    43.1769   47.325
# 28    26.2816  27.7031
# 29    28.1588  24.0734
# ...       ...      ...
# 2856  39.5668  37.3637
# 2857  56.2455  38.8329
# 2858  41.3718  39.3744
# 2859  22.7437  26.2023
# 2860  15.8845  21.5387
# 2861  45.5596  45.1503
# 2862  39.4224   45.247
# 2863  49.6029  37.4219
# 2864  47.0758  37.3117
# 2865  44.1877  37.4146
# 2866   18.917  24.5261
# 2867  15.8123   20.175
# 2868  19.4224  43.2989
# 2869  36.8231  46.2838
# 2870  37.4007  35.4625
# 2871  42.5993  38.2511
# 2872  39.0614  38.4504
# 2873  19.4224  25.9399
# 2874  17.4729  19.0952
# 2875  57.7617  41.8263
# 2876  39.9278  41.5569
# 2877   40.361  36.4069
# 2878  33.0686  43.4756
# 2879  33.2852  35.9809
# 2880  54.9458  46.5144
# 2881  33.7184   40.089
# 2882  37.7617  39.1877
# 2883  42.9603  37.1443
# 2884  18.7726  25.7708
# 2885  17.9783  18.4908
#
# [2886 rows x 8 columns]

# %% [markdown]
# ## valid index

# %%
predict_result = predict_three(trainArray[valid_idx], my_model, intervalDay)

day = trainArray[valid_idx, -1, 0]
true_kor = trainArray[valid_idx, -1, 1]
true_west = trainArray[valid_idx, -1, 2]
pred_kor = predict_result[:, 2, 0]
pred_west = predict_result[:, 2, 1]
week = trainArray[valid_idx, -1, 3]


pred_train = np.concatenate((day[:, np.newaxis],
                             true_kor[:, np.newaxis], true_west[:, np.newaxis],
                             pred_kor[:, np.newaxis], pred_west[:, np.newaxis],
                            week[:, np.newaxis]),
                            1)

pred_valid_df = pd.DataFrame(pred_train)
pred_valid_df.columns = ['date', 'true_kor', 'true_west', 
                         'pred_kor', 'pred_west', 'week']

pred_valid_df['true_sum'] = pred_valid_df['true_kor']+pred_valid_df['true_west']
pred_valid_df['pred_sum'] = pred_valid_df['pred_kor']+pred_valid_df['pred_west']

# %%
np.sqrt(np.mean(np.square(pred_valid_df['true_kor'] - pred_valid_df['pred_kor'] )))
# Out:
# 8.159146578644126

# %%
np.sqrt(np.mean(np.square(pred_valid_df['true_west'] - pred_valid_df['pred_west'] )))
# Out:
# 5.370219692401687

# %%
pred_valid_df
# Out:
#                     date true_kor true_west pred_kor pred_west week true_sum  \
# 0    2005-05-04 00:00:00  53.8628   14.4404  50.5176 -0.241431    2  68.3032
# 296  38.4246
# 297  38.6377
# 298  25.1821
# 299  20.4119
#
# [300 rows x 8 columns]

# %% [markdown]
# ## test index

# %% [markdown]
# predict_result_val = predict_three(validArray, my_model, intervalDay)
#
# day_val = validArray[:, -1, 0]
# true_kor_val = validArray[:, -1, 1]
# true_west_val = validArray[:, -1, 2]
# week_val = validArray[:, -1, 3]
# pred_kor_val = predict_result_val[:, -1, 0]
# pred_west_val = predict_result_val[:, -1, 1]
# pred_test = np.concatenate((day_val[:, np.newaxis],
#                              true_kor_val[:, np.newaxis], true_west_val[:, np.newaxis],
#                              pred_kor_val[:, np.newaxis], pred_west_val[:, np.newaxis],
#                            week_val[:, np.newaxis]),
#                             1)
#
# pred_test_df = pd.DataFrame(pred_test)
# pred_test_df.columns = ['date', 'true_kor', 'true_west',
#                          'pred_kor', 'pred_west', 'week']
#
# pred_test_df['true_sum'] = pred_test_df['true_kor']+pred_test_df['true_west']
# pred_test_df['pred_sum'] = pred_test_df['pred_kor']+pred_test_df['pred_west']

# %% [markdown]
# pred_test_df

# %% [markdown]
# ## predict

# %%
intervalDay+3
# Out:
# 6

# %%
realpredArray.shape
# Out:
# (57, 9, 5)

# %%
intervalDay
# Out:
# 3

# %%
result_ar = []
day_ar = []
pred_kor_ar = []
pred_west_ar = []
true_kor_ar = []
true_west_ar = []
week_ar = []
for i in range(0, 3):
    predict_result = predict_three(realpredArray[:, i:intervalDay+3+i, :], my_model, intervalDay)
    day_ar.append(realpredArray[:, [intervalDay+3+i], 0])
    pred_kor_ar.append(predict_result[:, [-1], 0])
    pred_west_ar.append(predict_result[:, [-1], 1])
    true_kor_ar.append(realpredArray[:, [intervalDay+3+i], 1])
    true_west_ar.append(realpredArray[:, [intervalDay+3+i], 2])
    week_ar.append(realpredArray[:, [intervalDay+3+i], 3])

# %%
pred_submit = np.concatenate((np.concatenate(day_ar, 1).reshape(-1, 1),
                             np.concatenate(true_kor_ar, 1).reshape(-1, 1), np.concatenate(true_west_ar, 1).reshape(-1, 1),
                             np.concatenate(pred_kor_ar, 1).reshape(-1, 1), np.concatenate(pred_west_ar, 1).reshape(-1, 1),
                             np.concatenate(week_ar, 1).reshape(-1, 1)),
                            1)

# %%
pred_submit_df = pd.DataFrame(pred_submit)
pred_submit_df.columns = ['date', 'true_kor', 'true_west', 
                         'pred_kor', 'pred_west', 'week']

pred_submit_df['true_sum'] = pred_submit_df['true_kor']+pred_submit_df['true_west']
pred_submit_df['pred_sum'] = pred_submit_df['pred_kor']+pred_submit_df['pred_west']

# %%
for i in range(37):
    print (pred_submit_df.set_index('date')[0+3*i:3+3*i])
# Out:
#            true_kor true_west pred_kor  pred_west week true_sum pred_sum
# date
# 2003-06-13        0         0  47.1556  -0.633471    0        0  46.5221
# 2003-06-14   33.213         0  26.4421 -0.0577592    5   33.213  26.3843
# 2003-06-15  24.5487         0   16.151    1.33471    6  24.5487  17.4857
#            true_kor true_west pred_kor  pred_west week true_sum pred_sum
# date
# 2004-02-28        0         0  27.1719 -0.0741264    0        0  27.0977
# 2004-02-29        0         0  23.1858   0.545316    0        0  23.7311
# 2004-03-01        0         0  40.5337    1.99692    0        0  42.5306
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2007-04-08        0         0   13.134   7.63221    0        0  20.7662
# 2007-04-09  44.7653   12.9964  39.2895    11.003    0  57.7617  50.2924
# 2007-04-10   32.491   11.5523  42.5572   9.76644    1  44.0433  52.3237
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2007-12-09        0         0  12.8793   7.51344    0        0  20.3928
# 2007-12-10  33.5018   18.0505  34.0541    11.067    0  51.5523  45.1212
# 2007-12-11  32.4188   10.8303  45.0828   9.38958    1  43.2491  54.4724
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2008-12-28        0         0   11.497   8.14341    0        0  19.6404
# 2008-12-29  40.2166   18.7726   40.147   12.6798    0  58.9892  52.8268
# 2008-12-30  31.5523   14.4404  44.2589   11.8555    1  45.9928  56.1144
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2009-01-21        0         0  33.9434   14.8259    0        0  48.7693
# 2009-01-22  35.2347   21.6606  36.0958   16.5721    3  56.8953   52.668
# 2009-01-23  32.3466   10.8303  41.0474   16.0731    4  43.1769  57.1205
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2009-07-15        0         0    31.34   15.2128    0        0  46.5528
# 2009-07-16        0         0  35.5509    13.856    0        0  49.4069
# 2009-07-17        0         0  40.3927   12.9932    0        0  53.3859
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2010-07-13        0         0  34.7816   18.4669    1        0  53.2485
# 2010-07-14        0         0  29.0011   17.7488    2        0  46.7499
# 2010-07-15        0         0  30.4436   14.6484    3        0  45.0919
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2011-03-09        0         0  20.8605   13.6597    2        0  34.5202
# 2011-03-10        0         0   22.288    13.511    3        0   35.799
# 2011-03-11        0         0  18.5945   12.2814    4        0  30.8759
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2011-05-03        0         0  25.8118   13.7986    1        0  39.6105
# 2011-05-04        0         0  24.0325   14.2718    2        0  38.3043
# 2011-05-05        0         0  27.0575   12.9807    3        0  40.0383
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2011-06-20        0         0  24.9722   13.0465    0        0  38.0188
# 2011-06-21        0         0  28.0432   16.4473    1        0  44.4905
# 2011-06-22        0         0  29.0577   12.8289    2        0  41.8866
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2011-07-16        0         0   12.866    11.453    5        0   24.319
# 2011-07-17        0         0   13.796   8.11175    6        0  21.9078
# 2011-07-18        0         0  27.2423   13.0235    0        0  40.2659
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2011-08-12        0         0  26.8926   14.9189    4        0  41.8115
# 2011-08-13        0         0  14.3811   12.3594    5        0  26.7405
# 2011-08-14        0         0  11.0353    9.4265    6        0  20.4618
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2011-09-12        0         0  17.3217    11.086    0        0  28.4077
# 2011-09-13        0         0  25.9081   12.7571    1        0  38.6652
# 2011-09-14        0         0  24.7033   11.2074    2        0  35.9108
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2011-10-18        0         0  26.9506   14.2899    1        0  41.2405
# 2011-10-19        0         0  21.4025    13.605    2        0  35.0076
# 2011-10-20        0         0  23.3126   13.9968    3        0  37.3094
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2012-01-01        0         0  10.9613    6.9029    6        0  17.8642
# 2012-01-02        0         0  20.8125   12.1704    0        0  32.9829
# 2012-01-03        0         0    20.19   11.8034    1        0  31.9934
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2012-03-12        0         0  29.9434   14.8295    0        0  44.7728
# 2012-03-13        0         0  26.0938   13.2409    1        0  39.3346
# 2012-03-14        0         0  23.7875    11.244    2        0  35.0315
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2012-05-11        0         0  27.1837   17.5506    4        0  44.7343
# 2012-05-12        0         0  13.5397    11.927    5        0  25.4667
# 2012-05-13        0         0   10.336   7.34734    6        0  17.6833
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2012-06-06        0         0  22.1789   13.3972    2        0  35.5761
# 2012-06-07        0         0  24.6535   14.7081    3        0  39.3616
# 2012-06-08        0         0  27.1822   15.5913    4        0  42.7734
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2012-06-30        0         0  15.4889   15.2641    0        0   30.753
# 2012-07-01   9.9639   7.43682  10.4705    8.3637    6  17.4007  18.8342
# 2012-07-02  16.1011   31.8412  24.5034   11.0559    0  47.9422  35.5593
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2012-07-25        0         0  20.4668   13.5267    2        0  33.9936
# 2012-07-26        0         0  27.6269   16.4272    3        0   44.054
# 2012-07-27        0         0  28.5932   15.1028    4        0   43.696
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2012-09-30        0         0  10.3818    8.4291    6        0  18.8109
# 2012-10-01        0         0  20.7148   11.2746    0        0  31.9894
# 2012-10-02        0         0  21.7535   11.5766    1        0    33.33
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2012-11-28        0         0  16.8116   11.3023    2        0  28.1139
# 2012-11-29        0         0  23.8394   14.0722    3        0  37.9117
# 2012-11-30        0         0   22.055   14.1952    4        0  36.2501
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2013-01-07        0         0  17.8316   10.8273    0        0  28.6588
# 2013-01-08        0         0  23.1497   13.5076    1        0  36.6573
# 2013-01-09        0         0  23.0983   11.9162    2        0  35.0145
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2013-02-26        0         0  27.0051    16.306    1        0  43.3111
# 2013-02-27        0         0  22.7989   15.2914    2        0  38.0903
# 2013-02-28        0         0    18.72   11.2683    3        0  29.9883
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2013-03-22        0         0   23.523   16.7598    4        0  40.2829
# 2013-03-23        0         0  14.0843   12.1501    5        0  26.2344
# 2013-03-24        0         0  10.8462   6.76918    6        0  17.6153
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2013-04-02        0         0  28.4483   15.6608    1        0  44.1091
# 2013-04-03        0         0  22.3673   12.6633    2        0  35.0307
# 2013-04-04        0         0  24.1097   11.3862    3        0  35.4959
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2013-07-29        0         0  29.8525   13.9913    0        0  43.8438
# 2013-07-30        0         0   32.611   14.1548    1        0  46.7658
# 2013-07-31        0         0  28.0384   11.4965    2        0  39.5348
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2013-08-11        0         0  10.0795   7.20176    6        0  17.2813
# 2013-08-12        0         0  33.0023   13.5449    0        0  46.5472
# 2013-08-13        0         0  34.5403   15.1392    1        0  49.6795
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2013-09-14        0         0    12.64   12.9636    5        0  25.6036
# 2013-09-15        0         0  12.5142   9.38309    6        0  21.8973
# 2013-09-16        0         0  21.3274    12.013    0        0  33.3404
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2014-03-17        0         0  21.2646   12.3477    0        0  33.6123
# 2014-03-18        0         0  24.5337   15.7073    1        0   40.241
# 2014-03-19        0         0  23.4185   11.2554    2        0   34.674
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2014-05-27        0         0  33.8899   15.7133    1        0  49.6032
# 2014-05-28        0         0  26.8225   14.2591    2        0  41.0816
# 2014-05-29        0         0  22.4783   13.5972    3        0  36.0756
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2014-06-29        0         0   11.754   7.59172    6        0  19.3457
# 2014-06-30        0         0  24.2408   13.1826    0        0  37.4233
# 2014-07-01        0         0  25.6728   14.7547    1        0  40.4276
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2014-08-20        0         0   29.098   13.3934    2        0  42.4914
# 2014-08-21        0         0  27.2783   15.0422    3        0  42.3204
# 2014-08-22        0         0  22.3068   12.3324    4        0  34.6392
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2014-10-08        0         0  26.6686   13.4958    2        0  40.1645
# 2014-10-09        0         0  29.4621    16.424    3        0  45.8861
# 2014-10-10        0         0   28.342   13.1448    4        0  41.4868
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2014-12-10        0         0  18.8909   12.9427    2        0  31.8335
# 2014-12-11        0         0  24.8718   12.2882    3        0    37.16
# 2014-12-12        0         0  15.3839   10.4222    4        0  25.8061
#            true_kor true_west pred_kor pred_west week true_sum pred_sum
# date
# 2015-01-18        0         0  10.9532   7.05364    6        0  18.0069
# 2015-01-19        0         0  28.9795   14.1466    0        0  43.1261
# 2015-01-20        0         0  27.2263   14.2482    1        0  41.4745

# %%
cPickle.dump([pred_train_df, pred_valid_df, pred_submit_df], open('RNNReuslt.pkl', 'wb'))
